# %% [markdown]
# COMP 215 - LAB 2 (NEO)
# ----------------
# #### Name:
# #### Date:
#
# This lab exercise is mostly a review of strings, tuples, lists, dictionaries, and functions.
#
# **Building on new concepts from lab 1**:
#   * *f-string* simplifies string formatting operations (like, a lot!)
#   * *list comprehension* provides a compact way to represent map and filter algorithms
#
# **New Python Concepts**:
#   * *f-string* simplifies string formatting operations (like, a lot!)
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# We'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/)
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# You should register for your own API key, (but may use the DEMO_KEY to get started).
#
# First we need a short tutorial on python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = datetime.date.today()   # get a date object representing today's date
print(today, type(today))
formatted_date = f'Today is: {today}'   # A format string - notice how the variable `today` is formatted into the stringg
print(formatted_date)
# Out:
# 2023-01-08 <class 'datetime.date'>
# Today is: 2023-01-08

# %% [markdown]
# ### Make a query
#
# Let's get some data from the NEO database...
# Here's a query that gets the observation "feed" for today:

# %%
API_KEY = 'DEMO_KEY'  # substitute your API key here

today = str(datetime.date.today())   # Today's date as a string!
# Use an f-string here to "format" the date and API key varaibles.
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

response = requests.request("GET", url, headers={}, data={})

data = json.loads(response.text)  # recall json.loads for lab 1

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = data['element_count']
neos = data['near_earth_objects'][today]
print(f'{n_results} Near Earth Objects found for {today}')
pprint(neos)
# Out:
# 11 Near Earth Objects found for 2023-01-08
# [{'absolute_magnitude_h': 18.16,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 16:16',
#                            'epoch_date_close_approach': 1673194560000,
#                            'miss_distance': {'astronomical': '0.168331259',
#                                              'kilometers': '25181997.80081833',
#                                              'lunar': '65.480859751',
#                                              'miles': '15647367.855339754'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '40230.2371096415',
#                                                  'kilometers_per_second': '11.1750658638',
#                                                  'miles_per_hour': '24997.5048307103'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 4550.142835581,
#                                   'estimated_diameter_min': 2034.8857375386},
#                          'kilometers': {'estimated_diameter_max': 1.3868834919,
#                                         'estimated_diameter_min': 0.620233153},
#                          'meters': {'estimated_diameter_max': 1386.8834919048,
#                                     'estimated_diameter_min': 620.2331529543},
#                          'miles': {'estimated_diameter_max': 0.8617691822,
#                                    'estimated_diameter_min': 0.3853948945}},
#   'id': '2199003',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2199003?api_key=DEMO_KEY'},
#   'name': '199003 (2005 WJ56)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2199003',
#   'neo_reference_id': '2199003'},
#  {'absolute_magnitude_h': 21.2,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 13:09',
#                            'epoch_date_close_approach': 1673183340000,
#                            'miss_distance': {'astronomical': '0.3748966171',
#                                              'kilometers': '56083735.388365577',
#                                              'lunar': '145.8347840519',
#                                              'miles': '34848817.2092038826'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '48935.8704731285',
#                                                  'kilometers_per_second': '13.5932973536',
#                                                  'miles_per_hour': '30406.8468503725'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1122.0831222578,
#                                   'estimated_diameter_min': 501.8108275547},
#                          'kilometers': {'estimated_diameter_max': 0.3420109247,
#                                         'estimated_diameter_min': 0.1529519353},
#                          'meters': {'estimated_diameter_max': 342.0109247198,
#                                     'estimated_diameter_min': 152.9519353442},
#                          'miles': {'estimated_diameter_max': 0.2125156703,
#                                    'estimated_diameter_min': 0.095039897}},
#   'id': '3023012',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3023012?api_key=DEMO_KEY'},
#   'name': '(1999 RA32)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3023012',
#   'neo_reference_id': '3023012'},
#  {'absolute_magnitude_h': 28.3,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 18:11',
#                            'epoch_date_close_approach': 1673201460000,
#                            'miss_distance': {'astronomical': '0.1834501503',
#                                              'kilometers': '27443751.736059861',
#                                              'lunar': '71.3621084667',
#                                              'miles': '17052756.5819576418'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '25132.3606737897',
#                                                  'kilometers_per_second': '6.9812112983',
#                                                  'miles_per_hour': '15616.2715531112'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 42.6604104873,
#                                   'estimated_diameter_min': 19.0783155595},
#                          'kilometers': {'estimated_diameter_max': 0.0130028927,
#                                         'estimated_diameter_min': 0.0058150704},
#                          'meters': {'estimated_diameter_max': 13.0028927004,
#                                     'estimated_diameter_min': 5.8150703965},
#                          'miles': {'estimated_diameter_max': 0.0080796204,
#                                    'estimated_diameter_min': 0.0036133161}},
#   'id': '3733849',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3733849?api_key=DEMO_KEY'},
#   'name': '(2015 VL64)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3733849',
#   'neo_reference_id': '3733849'},
#  {'absolute_magnitude_h': 22.29,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 21:21',
#                            'epoch_date_close_approach': 1673212860000,
#                            'miss_distance': {'astronomical': '0.2096490112',
#                                              'kilometers': '31363045.523126144',
#                                              'lunar': '81.5534653568',
#                                              'miles': '19488092.8131990272'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '47884.806170428',
#                                                  'kilometers_per_second': '13.3013350473',
#                                                  'miles_per_hour': '29753.7563673973'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 679.2427787741,
#                                   'estimated_diameter_min': 303.766605313},
#                          'kilometers': {'estimated_diameter_max': 0.2070331923,
#                                         'estimated_diameter_min': 0.0925880583},
#                          'meters': {'estimated_diameter_max': 207.0331923453,
#                                     'estimated_diameter_min': 92.5880583366},
#                          'miles': {'estimated_diameter_max': 0.1286444218,
#                                    'estimated_diameter_min': 0.0575315344}},
#   'id': '3736406',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3736406?api_key=DEMO_KEY'},
#   'name': '(2015 XN169)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3736406',
#   'neo_reference_id': '3736406'},
#  {'absolute_magnitude_h': 21.19,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 07:11',
#                            'epoch_date_close_approach': 1673161860000,
#                            'miss_distance': {'astronomical': '0.4723679384',
#                                              'kilometers': '70665237.440931208',
#                                              'lunar': '183.7511280376',
#                                              'miles': '43909342.4425303504'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '51547.5320963216',
#                                                  'kilometers_per_second': '14.3187589156',
#                                                  'miles_per_hour': '32029.6318184061'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1127.262422625,
#                                   'estimated_diameter_min': 504.1270810941},
#                          'kilometers': {'estimated_diameter_max': 0.3435895754,
#                                         'estimated_diameter_min': 0.1536579294},
#                          'meters': {'estimated_diameter_max': 343.5895754212,
#                                     'estimated_diameter_min': 153.6579294004},
#                          'miles': {'estimated_diameter_max': 0.2134965981,
#                                    'estimated_diameter_min': 0.0954785812}},
#   'id': '3841196',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3841196?api_key=DEMO_KEY'},
#   'name': '(2019 GJ20)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3841196',
#   'neo_reference_id': '3841196'},
#  {'absolute_magnitude_h': 22.37,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 08:48',
#                            'epoch_date_close_approach': 1673167680000,
#                            'miss_distance': {'astronomical': '0.3592405556',
#                                              'kilometers': '53741621.935376572',
#                                              'lunar': '139.7445761284',
#                                              'miles': '33393495.3936858136'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '49622.3121903898',
#                                                  'kilometers_per_second': '13.7839756084',
#                                                  'miles_per_hour': '30833.375038523'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 654.6739042695,
#                                   'estimated_diameter_min': 292.7790706084},
#                          'kilometers': {'estimated_diameter_max': 0.1995445996,
#                                         'estimated_diameter_min': 0.0892390579},
#                          'meters': {'estimated_diameter_max': 199.5445996359,
#                                     'estimated_diameter_min': 89.2390578658},
#                          'miles': {'estimated_diameter_max': 0.1239912274,
#                                    'estimated_diameter_min': 0.0554505626}},
#   'id': '54051126',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54051126?api_key=DEMO_KEY'},
#   'name': '(2020 PH5)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54051126',
#   'neo_reference_id': '54051126'},
#  {'absolute_magnitude_h': 23.68,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 23:26',
#                            'epoch_date_close_approach': 1673220360000,
#                            'miss_distance': {'astronomical': '0.1580783516',
#                                              'kilometers': '23648184.692471092',
#                                              'lunar': '61.4924787724',
#                                              'miles': '14694300.5841293896'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '45220.1506028003',
#                                                  'kilometers_per_second': '12.5611529452',
#                                                  'miles_per_hour': '28098.0430231678'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 358.1170761255,
#                                   'estimated_diameter_min': 160.154825224},
#                          'kilometers': {'estimated_diameter_max': 0.1091540813,
#                                         'estimated_diameter_min': 0.0488151892},
#                          'meters': {'estimated_diameter_max': 109.1540813101,
#                                     'estimated_diameter_min': 48.8151891662},
#                          'miles': {'estimated_diameter_max': 0.0678251807,
#                                    'estimated_diameter_min': 0.0303323429}},
#   'id': '54104550',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54104550?api_key=DEMO_KEY'},
#   'name': '(2021 AP1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54104550',
#   'neo_reference_id': '54104550'},
#  {'absolute_magnitude_h': 23.61,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 02:59',
#                            'epoch_date_close_approach': 1673146740000,
#                            'miss_distance': {'astronomical': '0.2926342877',
#                                              'kilometers': '43777466.128887199',
#                                              'lunar': '113.8347379153',
#                                              'miles': '27202056.0763893862'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '73951.2137461939',
#                                                  'kilometers_per_second': '20.5420038184',
#                                                  'miles_per_hour': '45950.4083413503'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 369.8494949666,
#                                   'estimated_diameter_min': 165.4017224378},
#                          'kilometers': {'estimated_diameter_max': 0.1127301225,
#                                         'estimated_diameter_min': 0.0504144434},
#                          'meters': {'estimated_diameter_max': 112.7301224584,
#                                     'estimated_diameter_min': 50.4144433858},
#                          'miles': {'estimated_diameter_max': 0.0700472289,
#                                    'estimated_diameter_min': 0.0313260731}},
#   'id': '54104901',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54104901?api_key=DEMO_KEY'},
#   'name': '(2021 AJ3)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54104901',
#   'neo_reference_id': '54104901'},
#  {'absolute_magnitude_h': 25.35,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 15:28',
#                            'epoch_date_close_approach': 1673191680000,
#                            'miss_distance': {'astronomical': '0.2372521744',
#                                              'kilometers': '35492419.943108528',
#                                              'lunar': '92.2910958416',
#                                              'miles': '22053967.0966045664'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '27018.4894663548',
#                                                  'kilometers_per_second': '7.5051359629',
#                                                  'miles_per_hour': '16788.238635358'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 165.9682558353,
#                                   'estimated_diameter_min': 74.223260431},
#                          'kilometers': {'estimated_diameter_max': 0.0505871228,
#                                         'estimated_diameter_min': 0.0226232491},
#                          'meters': {'estimated_diameter_max': 50.5871227598,
#                                     'estimated_diameter_min': 22.6232490554},
#                          'miles': {'estimated_diameter_max': 0.0314333711,
#                                    'estimated_diameter_min': 0.0140574309}},
#   'id': '54240292',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54240292?api_key=DEMO_KEY'},
#   'name': '(2022 BS2)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54240292',
#   'neo_reference_id': '54240292'},
#  {'absolute_magnitude_h': 21.82,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 21:15',
#                            'epoch_date_close_approach': 1673212500000,
#                            'miss_distance': {'astronomical': '0.2223551782',
#                                              'kilometers': '33263861.042190434',
#                                              'lunar': '86.4961643198',
#                                              'miles': '20669204.8078546292'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '45818.7957028364',
#                                                  'kilometers_per_second': '12.7274432508',
#                                                  'miles_per_hour': '28470.0178076875'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 843.3833636804,
#                                   'estimated_diameter_min': 377.1725064563},
#                          'kilometers': {'estimated_diameter_max': 0.257063241,
#                                         'estimated_diameter_min': 0.1149621763},
#                          'meters': {'estimated_diameter_max': 257.0632410238,
#                                     'estimated_diameter_min': 114.9621762891},
#                          'miles': {'estimated_diameter_max': 0.1597316431,
#                                    'estimated_diameter_min': 0.0714341624}},
#   'id': '54317881',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54317881?api_key=DEMO_KEY'},
#   'name': '(2022 UH4)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54317881',
#   'neo_reference_id': '54317881'},
#  {'absolute_magnitude_h': 22.09,
#   'close_approach_data': [{'close_approach_date': '2023-01-08',
#                            'close_approach_date_full': '2023-Jan-08 11:59',
#                            'epoch_date_close_approach': 1673179140000,
#                            'miss_distance': {'astronomical': '0.2100601675',
#                                              'kilometers': '31424553.629843225',
#                                              'lunar': '81.7134051575',
#                                              'miles': '19526312.178457505'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '43880.2449109978',
#                                                  'kilometers_per_second': '12.1889569197',
#                                                  'miles_per_hour': '27265.4777337252'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 744.7748968135,
#                                   'estimated_diameter_min': 333.0734594421},
#                          'kilometers': {'estimated_diameter_max': 0.2270073813,
#                                         'estimated_diameter_min': 0.1015207872},
#                          'meters': {'estimated_diameter_max': 227.0073812845,
#                                     'estimated_diameter_min': 101.5207871893},
#                          'miles': {'estimated_diameter_max': 0.1410558035,
#                                    'estimated_diameter_min': 0.0630820731}},
#   'id': '54326521',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54326521?api_key=DEMO_KEY'},
#   'name': '(2022 UJ65)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54326521',
#   'neo_reference_id': '54326521'}]

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0):

# %%
hazards = [item for item in neos if item['is_potentially_hazardous_asteroid']==True]
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 2 potentially hazardous asteroids identified.

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the "list comprehension" above** as a loop so you understand how it works.
# Notice how this kind of "conditional" list comprehension is a compact way to "filter" items of interest from a large data set.

# %%
# Your code here

# %% [markdown]
# ## Fetch Compelte Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the first hazardous asteroid...

# %%
id = hazards[0]['id']
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

pprint(data)
# Out:
# {'absolute_magnitude_h': 18.16,
#  'close_approach_data': [{'close_approach_date': '1900-05-30',
#                           'close_approach_date_full': '1900-May-30 12:17',
#                           'epoch_date_close_approach': -2196070980000,
#                           'miss_distance': {'astronomical': '0.325240682',
#                                             'kilometers': '48655313.26454734',
#                                             'lunar': '126.518625298',
#                                             'miles': '30233009.739299692'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '43482.3471444013',
#                                                 'kilometers_per_second': '12.0784297623',
#                                                 'miles_per_hour': '27018.2395353643'}},
#                          {'close_approach_date': '1901-01-09',
#                           'close_approach_date_full': '1901-Jan-09 01:53',
#                           'epoch_date_close_approach': -2176754820000,
#                           'miss_distance': {'astronomical': '0.0371161321',
#                                             'kilometers': '5552494.304798627',
#                                             'lunar': '14.4381753869',
#                                             'miles': '3450159.9749579726'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44353.1536458109',
#                                                 'kilometers_per_second': '12.3203204572',
#                                                 'miles_per_hour': '27559.3248306429'}},
#                          {'close_approach_date': '1901-12-31',
#                           'close_approach_date_full': '1901-Dec-31 05:19',
#                           'epoch_date_close_approach': -2145984060000,
#                           'miss_distance': {'astronomical': '0.4035574632',
#                                             'kilometers': '60371336.917323384',
#                                             'lunar': '156.9838531848',
#                                             'miles': '37513009.2590713392'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72869.676402708',
#                                                 'kilometers_per_second': '20.2415767785',
#                                                 'miles_per_hour': '45278.3830958938'}},
#                          {'close_approach_date': '1904-03-12',
#                           'close_approach_date_full': '1904-Mar-12 04:45',
#                           'epoch_date_close_approach': -2076693300000,
#                           'miss_distance': {'astronomical': '0.1352471972',
#                                             'kilometers': '20232692.624589964',
#                                             'lunar': '52.6111597108',
#                                             'miles': '12572012.2249669432'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '54383.37152157',
#                                                 'kilometers_per_second': '15.1064920893',
#                                                 'miles_per_hour': '33791.7121546111'}},
#                          {'close_approach_date': '1913-08-26',
#                           'close_approach_date_full': '1913-Aug-26 15:09',
#                           'epoch_date_close_approach': -1778230260000,
#                           'miss_distance': {'astronomical': '0.4685598354',
#                                             'kilometers': '70095553.343390598',
#                                             'lunar': '182.2697759706',
#                                             'miles': '43555357.1588343324'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '74053.3969634303',
#                                                 'kilometers_per_second': '20.5703880454',
#                                                 'miles_per_hour': '46013.9010187492'}},
#                          {'close_approach_date': '1914-07-28',
#                           'close_approach_date_full': '1914-Jul-28 17:29',
#                           'epoch_date_close_approach': -1749191460000,
#                           'miss_distance': {'astronomical': '0.1695237075',
#                                             'kilometers': '25360385.556503025',
#                                             'lunar': '65.9447222175',
#                                             'miles': '15758212.866770745'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '49430.3014917122',
#                                                 'kilometers_per_second': '13.7306393033',
#                                                 'miles_per_hour': '30714.0670574475'}},
#                          {'close_approach_date': '1914-12-14',
#                           'close_approach_date_full': '1914-Dec-14 19:04',
#                           'epoch_date_close_approach': -1737176160000,
#                           'miss_distance': {'astronomical': '0.4123699042',
#                                             'kilometers': '61689659.320424054',
#                                             'lunar': '160.4118927338',
#                                             'miles': '38332176.8150537852'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44412.0830200793',
#                                                 'kilometers_per_second': '12.3366897278',
#                                                 'miles_per_hour': '27595.9412521154'}},
#                          {'close_approach_date': '1915-06-17',
#                           'close_approach_date_full': '1915-Jun-17 09:55',
#                           'epoch_date_close_approach': -1721225100000,
#                           'miss_distance': {'astronomical': '0.2551334835',
#                                             'kilometers': '38167425.697280145',
#                                             'lunar': '99.2469250815',
#                                             'miles': '23716138.596330201'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44276.476391096',
#                                                 'kilometers_per_second': '12.2990212197',
#                                                 'miles_per_hour': '27511.6805664563'}},
#                          {'close_approach_date': '1916-01-10',
#                           'close_approach_date_full': '1916-Jan-10 04:56',
#                           'epoch_date_close_approach': -1703358240000,
#                           'miss_distance': {'astronomical': '0.0760296044',
#                                             'kilometers': '11373866.875182628',
#                                             'lunar': '29.5755161116',
#                                             'miles': '7067393.1568631464'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40882.3214567029',
#                                                 'kilometers_per_second': '11.3562004046',
#                                                 'miles_per_hour': '25402.6846851385'}},
#                          {'close_approach_date': '1917-01-03',
#                           'close_approach_date_full': '1917-Jan-03 08:38',
#                           'epoch_date_close_approach': -1672327320000,
#                           'miss_distance': {'astronomical': '0.2972118041',
#                                             'kilometers': '44462252.832217267',
#                                             'lunar': '115.6153917949',
#                                             'miles': '27627562.8028296046'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63080.6532450696',
#                                                 'kilometers_per_second': '17.5224036792',
#                                                 'miles_per_hour': '39195.8647899712'}},
#                          {'close_approach_date': '1922-01-13',
#                           'close_approach_date_full': '1922-Jan-13 22:02',
#                           'epoch_date_close_approach': -1513648680000,
#                           'miss_distance': {'astronomical': '0.1353899131',
#                                             'kilometers': '20254042.619245097',
#                                             'lunar': '52.6666761959',
#                                             'miles': '12585278.4964804586'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '53550.131693341',
#                                                 'kilometers_per_second': '14.8750365815',
#                                                 'miles_per_hour': '33273.9693291207'}},
#                          {'close_approach_date': '1929-08-09',
#                           'close_approach_date_full': '1929-Aug-09 19:45',
#                           'epoch_date_close_approach': -1274760900000,
#                           'miss_distance': {'astronomical': '0.2721403637',
#                                             'kilometers': '40711618.750545319',
#                                             'lunar': '105.8626014793',
#                                             'miles': '25297026.8528666422'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57096.5251901818',
#                                                 'kilometers_per_second': '15.8601458862',
#                                                 'miles_per_hour': '35477.5603327549'}},
#                          {'close_approach_date': '1930-07-05',
#                           'close_approach_date_full': '1930-Jul-05 19:03',
#                           'epoch_date_close_approach': -1246251420000,
#                           'miss_distance': {'astronomical': '0.1642683089',
#                                             'kilometers': '24574189.119942043',
#                                             'lunar': '63.9003721621',
#                                             'miles': '15269693.0540564734'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44260.1278896539',
#                                                 'kilometers_per_second': '12.2944799693',
#                                                 'miles_per_hour': '27501.5222434352'}},
#                          {'close_approach_date': '1931-01-06',
#                           'close_approach_date_full': '1931-Jan-06 18:53',
#                           'epoch_date_close_approach': -1230268020000,
#                           'miss_distance': {'astronomical': '0.2169980003',
#                                             'kilometers': '32462438.639139361',
#                                             'lunar': '84.4122221167',
#                                             'miles': '20171224.0182747418'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40878.2632613458',
#                                                 'kilometers_per_second': '11.3550731282',
#                                                 'miles_per_hour': '25400.1630803623'}},
#                          {'close_approach_date': '1932-01-08',
#                           'close_approach_date_full': '1932-Jan-08 00:01',
#                           'epoch_date_close_approach': -1198627140000,
#                           'miss_distance': {'astronomical': '0.1495122803',
#                                             'kilometers': '22366718.671722961',
#                                             'lunar': '58.1602770367',
#                                             'miles': '13898034.5221844218'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '51312.0833417437',
#                                                 'kilometers_per_second': '14.2533564838',
#                                                 'miles_per_hour': '31883.3331186518'}},
#                          {'close_approach_date': '1939-11-17',
#                           'close_approach_date_full': '1939-Nov-17 03:55',
#                           'epoch_date_close_approach': -950645100000,
#                           'miss_distance': {'astronomical': '0.1350602637',
#                                             'kilometers': '20204727.771158319',
#                                             'lunar': '52.5384425793',
#                                             'miles': '12554635.6708060422'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '53611.2777696566',
#                                                 'kilometers_per_second': '14.8920216027',
#                                                 'miles_per_hour': '33311.9631230403'}},
#                          {'close_approach_date': '1944-08-20',
#                           'close_approach_date_full': '1944-Aug-20 04:56',
#                           'epoch_date_close_approach': -800478240000,
#                           'miss_distance': {'astronomical': '0.3901034539',
#                                             'kilometers': '58358645.783083193',
#                                             'lunar': '151.7502435671',
#                                             'miles': '36262380.9806583434'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '66925.7316663682',
#                                                 'kilometers_per_second': '18.5904810184',
#                                                 'miles_per_hour': '41585.0469901386'}},
#                          {'close_approach_date': '1945-07-20',
#                           'close_approach_date_full': '1945-Jul-20 05:25',
#                           'epoch_date_close_approach': -771618900000,
#                           'miss_distance': {'astronomical': '0.1359128952',
#                                             'kilometers': '20332279.627453224',
#                                             'lunar': '52.8701162328',
#                                             'miles': '12633892.7191095312'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '46418.489196237',
#                                                 'kilometers_per_second': '12.8940247767',
#                                                 'miles_per_hour': '28842.6440230729'}},
#                          {'close_approach_date': '1945-12-27',
#                           'close_approach_date_full': '1945-Dec-27 19:29',
#                           'epoch_date_close_approach': -757744260000,
#                           'miss_distance': {'astronomical': '0.3412463427',
#                                             'kilometers': '51049726.013210049',
#                                             'lunar': '132.7448273103',
#                                             'miles': '31720828.8302307162'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '43881.508268167',
#                                                 'kilometers_per_second': '12.1893078523',
#                                                 'miles_per_hour': '27266.2627347396'}},
#                          {'close_approach_date': '1946-06-03',
#                           'close_approach_date_full': '1946-Jun-03 18:47',
#                           'epoch_date_close_approach': -744095580000,
#                           'miss_distance': {'astronomical': '0.3120373163',
#                                             'kilometers': '46680117.878996281',
#                                             'lunar': '121.3825160407',
#                                             'miles': '29005680.2387434378'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '43886.7268378888',
#                                                 'kilometers_per_second': '12.190757455',
#                                                 'miles_per_hour': '27269.5053510204'}},
#                          {'close_approach_date': '1947-01-09',
#                           'close_approach_date_full': '1947-Jan-09 20:58',
#                           'epoch_date_close_approach': -725079720000,
#                           'miss_distance': {'astronomical': '0.0250346092',
#                                             'kilometers': '3745124.212602404',
#                                             'lunar': '9.7384629788',
#                                             'miles': '2327112.2760810152'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '43511.8794124892',
#                                                 'kilometers_per_second': '12.0866331701',
#                                                 'miles_per_hour': '27036.589738277'}},
#                          {'close_approach_date': '1948-01-01',
#                           'close_approach_date_full': '1948-Jan-01 10:32',
#                           'epoch_date_close_approach': -694272480000,
#                           'miss_distance': {'astronomical': '0.3867331536',
#                                             'kilometers': '57854456.036942832',
#                                             'lunar': '150.4391967504',
#                                             'miles': '35949091.9998098016'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '71297.5197343342',
#                                                 'kilometers_per_second': '19.8048665929',
#                                                 'miles_per_hour': '44301.5060815922'}},
#                          {'close_approach_date': '1959-08-26',
#                           'close_approach_date_full': '1959-Aug-26 16:35',
#                           'epoch_date_close_approach': -326618700000,
#                           'miss_distance': {'astronomical': '0.4585165871',
#                                             'kilometers': '68593104.789829477',
#                                             'lunar': '178.3629523819',
#                                             'miles': '42621778.9182497026'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '73047.1882965995',
#                                                 'kilometers_per_second': '20.2908856379',
#                                                 'miles_per_hour': '45388.6820835176'}},
#                          {'close_approach_date': '1960-07-27',
#                           'close_approach_date_full': '1960-Jul-27 02:09',
#                           'epoch_date_close_approach': -297640260000,
#                           'miss_distance': {'astronomical': '0.1626909023',
#                                             'kilometers': '24338212.452458101',
#                                             'lunar': '63.2867609947',
#                                             'miles': '15123063.9521637538'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '48855.4951112752',
#                                                 'kilometers_per_second': '13.5709708642',
#                                                 'miles_per_hour': '30356.9047262254'}},
#                          {'close_approach_date': '1960-12-17',
#                           'close_approach_date_full': '1960-Dec-17 08:21',
#                           'epoch_date_close_approach': -285262740000,
#                           'miss_distance': {'astronomical': '0.3999034712',
#                                             'kilometers': '59824707.497126344',
#                                             'lunar': '155.5624502968',
#                                             'miles': '37173349.4875937872'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44549.7780544495',
#                                                 'kilometers_per_second': '12.3749383485',
#                                                 'miles_per_hour': '27681.4995916661'}},
#                          {'close_approach_date': '1961-06-14',
#                           'close_approach_date_full': '1961-Jun-14 11:09',
#                           'epoch_date_close_approach': -269787060000,
#                           'miss_distance': {'astronomical': '0.2668424194',
#                                             'kilometers': '39919057.567886678',
#                                             'lunar': '103.8017011466',
#                                             'miles': '24804552.1703170364'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44319.1391706607',
#                                                 'kilometers_per_second': '12.3108719919',
#                                                 'miles_per_hour': '27538.1895585697'}},
#                          {'close_approach_date': '1962-01-09',
#                           'close_approach_date_full': '1962-Jan-09 20:35',
#                           'epoch_date_close_approach': -251695500000,
#                           'miss_distance': {'astronomical': '0.0590750748',
#                                             'kilometers': '8837505.360170676',
#                                             'lunar': '22.9802040972',
#                                             'miles': '5491371.1925442888'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '41278.7778623802',
#                                                 'kilometers_per_second': '11.466327184',
#                                                 'miles_per_hour': '25649.0272778773'}},
#                          {'close_approach_date': '1963-01-03',
#                           'close_approach_date_full': '1963-Jan-03 09:58',
#                           'epoch_date_close_approach': -220716120000,
#                           'miss_distance': {'astronomical': '0.3175028722',
#                                             'kilometers': '47497753.400002214',
#                                             'lunar': '123.5086172858',
#                                             'miles': '29513735.3926659932'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64875.0305247505',
#                                                 'kilometers_per_second': '18.0208418124',
#                                                 'miles_per_hour': '40310.8210502262'}},
#                          {'close_approach_date': '1975-08-07',
#                           'close_approach_date_full': '1975-Aug-07 10:58',
#                           'epoch_date_close_approach': 176641080000,
#                           'miss_distance': {'astronomical': '0.2429704247',
#                                             'kilometers': '36347858.008115389',
#                                             'lunar': '94.5154952083',
#                                             'miles': '22585511.6621508082'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '54803.0094162491',
#                                                 'kilometers_per_second': '15.2230581712',
#                                                 'miles_per_hour': '34052.4588231132'}},
#                          {'close_approach_date': '1976-06-30',
#                           'close_approach_date_full': '1976-Jun-30 17:31',
#                           'epoch_date_close_approach': 205003860000,
#                           'miss_distance': {'astronomical': '0.1864928432',
#                                             'kilometers': '27898932.112963984',
#                                             'lunar': '72.5457160048',
#                                             'miles': '17335592.5528876192'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44142.6355473218',
#                                                 'kilometers_per_second': '12.2618432076',
#                                                 'miles_per_hour': '27428.5170710567'}},
#                          {'close_approach_date': '1977-01-07',
#                           'close_approach_date_full': '1977-Jan-07 19:01',
#                           'epoch_date_close_approach': 221511660000,
#                           'miss_distance': {'astronomical': '0.1788277561',
#                                             'kilometers': '26752251.409439507',
#                                             'lunar': '69.5639971229',
#                                             'miles': '16623078.2034469166'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40334.8899823985',
#                                                 'kilometers_per_second': '11.2041361062',
#                                                 'miles_per_hour': '25062.5320560075'}},
#                          {'close_approach_date': '1978-01-06',
#                           'close_approach_date_full': '1978-Jan-06 15:45',
#                           'epoch_date_close_approach': 252949500000,
#                           'miss_distance': {'astronomical': '0.1918388349',
#                                             'kilometers': '28698681.084321663',
#                                             'lunar': '74.6253067761',
#                                             'miles': '17832533.5202304294'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '54438.630838888',
#                                                 'kilometers_per_second': '15.1218418997',
#                                                 'miles_per_hour': '33826.048145419'}},
#                          {'close_approach_date': '1990-08-17',
#                           'close_approach_date_full': '1990-Aug-17 07:53',
#                           'epoch_date_close_approach': 650879580000,
#                           'miss_distance': {'astronomical': '0.3481285612',
#                                             'kilometers': '52079291.241684644',
#                                             'lunar': '135.4220103068',
#                                             'miles': '32360570.9979663272'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '63234.356979101',
#                                                 'kilometers_per_second': '17.5650991609',
#                                                 'miles_per_hour': '39291.3703129309'}},
#                          {'close_approach_date': '1991-07-15',
#                           'close_approach_date_full': '1991-Jul-15 21:36',
#                           'epoch_date_close_approach': 679613760000,
#                           'miss_distance': {'astronomical': '0.1353307341',
#                                             'kilometers': '20245189.566896367',
#                                             'lunar': '52.6436555649',
#                                             'miles': '12579777.4648371846'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '45319.9321482246',
#                                                 'kilometers_per_second': '12.5888700412',
#                                                 'miles_per_hour': '28160.043395101'}},
#                          {'close_approach_date': '1992-01-01',
#                           'close_approach_date_full': '1992-Jan-01 17:04',
#                           'epoch_date_close_approach': 694285440000,
#                           'miss_distance': {'astronomical': '0.2985231349',
#                                             'kilometers': '44658425.126762663',
#                                             'lunar': '116.1254994761',
#                                             'miles': '27749458.6142762294'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42753.5098393727',
#                                                 'kilometers_per_second': '11.8759749554',
#                                                 'miles_per_hour': '26565.3683776924'}},
#                          {'close_approach_date': '1992-05-24',
#                           'close_approach_date_full': '1992-May-24 15:36',
#                           'epoch_date_close_approach': 706721760000,
#                           'miss_distance': {'astronomical': '0.343020571',
#                                             'kilometers': '51315146.78778377',
#                                             'lunar': '133.435002119',
#                                             'miles': '31885753.651885226'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42540.3114488186',
#                                                 'kilometers_per_second': '11.8167531802',
#                                                 'miles_per_hour': '26432.8951888507'}},
#                          {'close_approach_date': '1993-01-08',
#                           'close_approach_date_full': '1993-Jan-08 22:22',
#                           'epoch_date_close_approach': 726531720000,
#                           'miss_distance': {'astronomical': '0.0647384277',
#                                             'kilometers': '9684730.891068999',
#                                             'lunar': '25.1832483753',
#                                             'miles': '6017812.7260262262'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '45866.817574978',
#                                                 'kilometers_per_second': '12.7407826597',
#                                                 'miles_per_hour': '28499.8567315189'}},
#                          {'close_approach_date': '1993-12-30',
#                           'close_approach_date_full': '1993-Dec-30 09:02',
#                           'epoch_date_close_approach': 757242120000,
#                           'miss_distance': {'astronomical': '0.4361234376',
#                                             'kilometers': '65243137.322037912',
#                                             'lunar': '169.6520172264',
#                                             'miles': '40540205.6575987056'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '75962.5133846198',
#                                                 'kilometers_per_second': '21.1006981624',
#                                                 'miles_per_hour': '47200.15171946'}},
#                          {'close_approach_date': '1995-03-30',
#                           'close_approach_date_full': '1995-Mar-30 02:04',
#                           'epoch_date_close_approach': 796529040000,
#                           'miss_distance': {'astronomical': '0.148802692',
#                                             'kilometers': '22260565.77346604',
#                                             'lunar': '57.884247188',
#                                             'miles': '13832074.169829752'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '56346.253531897',
#                                                 'kilometers_per_second': '15.6517370922',
#                                                 'miles_per_hour': '35011.3707015279'}},
#                          {'close_approach_date': '2005-08-23',
#                           'close_approach_date_full': '2005-Aug-23 08:35',
#                           'epoch_date_close_approach': 1124786100000,
#                           'miss_distance': {'astronomical': '0.4207139654',
#                                             'kilometers': '62937913.103093698',
#                                             'lunar': '163.6577325406',
#                                             'miles': '39107805.7492131124'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69561.2710532426',
#                                                 'kilometers_per_second': '19.3225752926',
#                                                 'miles_per_hour': '43222.668671944'}},
#                          {'close_approach_date': '2006-07-23',
#                           'close_approach_date_full': '2006-Jul-23 18:43',
#                           'epoch_date_close_approach': 1153680180000,
#                           'miss_distance': {'astronomical': '0.1452715629',
#                                             'kilometers': '21732316.381411023',
#                                             'lunar': '56.5106379681',
#                                             'miles': '13503835.2182491974'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '47373.6949801441',
#                                                 'kilometers_per_second': '13.1593597167',
#                                                 'miles_per_hour': '29436.1717503012'}},
#                          {'close_approach_date': '2006-12-24',
#                           'close_approach_date_full': '2006-Dec-24 04:34',
#                           'epoch_date_close_approach': 1166934840000,
#                           'miss_distance': {'astronomical': '0.3671350556',
#                                             'kilometers': '54922622.320091572',
#                                             'lunar': '142.8155366284',
#                                             'miles': '34127335.0041528136'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44347.0318490264',
#                                                 'kilometers_per_second': '12.3186199581',
#                                                 'miles_per_hour': '27555.5209841909'}},
#                          {'close_approach_date': '2007-06-08',
#                           'close_approach_date_full': '2007-Jun-08 21:14',
#                           'epoch_date_close_approach': 1181337240000,
#                           'miss_distance': {'astronomical': '0.2930787794',
#                                             'kilometers': '43843961.140439878',
#                                             'lunar': '114.0076451866',
#                                             'miles': '27243374.1606231964'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44206.8454260392',
#                                                 'kilometers_per_second': '12.279679285',
#                                                 'miles_per_hour': '27468.4145926409'}},
#                          {'close_approach_date': '2008-01-10',
#                           'close_approach_date_full': '2008-Jan-10 10:20',
#                           'epoch_date_close_approach': 1199960400000,
#                           'miss_distance': {'astronomical': '0.0279109043',
#                                             'kilometers': '4175411.833053841',
#                                             'lunar': '10.8573417727',
#                                             'miles': '2594480.6053953658'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42440.11175111',
#                                                 'kilometers_per_second': '11.7889199309',
#                                                 'miles_per_hour': '26370.6349933495'}},
#                          {'close_approach_date': '2009-01-01',
#                           'close_approach_date_full': '2009-Jan-01 22:25',
#                           'epoch_date_close_approach': 1230848700000,
#                           'miss_distance': {'astronomical': '0.3540354489',
#                                             'kilometers': '52962949.059933843',
#                                             'lunar': '137.7197896221',
#                                             'miles': '32909650.5050713134'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '68212.4968071216',
#                                                 'kilometers_per_second': '18.9479157798',
#                                                 'miles_per_hour': '42384.5928077362'}},
#                          {'close_approach_date': '2013-01-31',
#                           'close_approach_date_full': '2013-Jan-31 00:41',
#                           'epoch_date_close_approach': 1359592860000,
#                           'miss_distance': {'astronomical': '0.1340424796',
#                                             'kilometers': '20052469.437678452',
#                                             'lunar': '52.1425245644',
#                                             'miles': '12460026.7294565576'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '54127.4368511128',
#                                                 'kilometers_per_second': '15.0353991253',
#                                                 'miles_per_hour': '33632.6843034039'}},
#                          {'close_approach_date': '2021-08-05',
#                           'close_approach_date_full': '2021-Aug-05 14:45',
#                           'epoch_date_close_approach': 1628174700000,
#                           'miss_distance': {'astronomical': '0.2299034527',
#                                             'kilometers': '34393066.829565749',
#                                             'lunar': '89.4324431003',
#                                             'miles': '21370860.7479113762'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '53822.0632424249',
#                                                 'kilometers_per_second': '14.9505731229',
#                                                 'miles_per_hour': '33442.9370186056'}},
#                          {'close_approach_date': '2022-06-29',
#                           'close_approach_date_full': '2022-Jun-29 14:31',
#                           'epoch_date_close_approach': 1656513060000,
#                           'miss_distance': {'astronomical': '0.1947587592',
#                                             'kilometers': '29135495.540162904',
#                                             'lunar': '75.7611573288',
#                                             'miles': '18103957.4369959152'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44124.5577493994',
#                                                 'kilometers_per_second': '12.2568215971',
#                                                 'miles_per_hour': '27417.2842304532'}},
#                          {'close_approach_date': '2023-01-08',
#                           'close_approach_date_full': '2023-Jan-08 16:16',
#                           'epoch_date_close_approach': 1673194560000,
#                           'miss_distance': {'astronomical': '0.168331259',
#                                             'kilometers': '25181997.80081833',
#                                             'lunar': '65.480859751',
#                                             'miles': '15647367.855339754'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40230.2371096415',
#                                                 'kilometers_per_second': '11.1750658638',
#                                                 'miles_per_hour': '24997.5048307103'}},
#                          {'close_approach_date': '2024-01-07',
#                           'close_approach_date_full': '2024-Jan-07 02:32',
#                           'epoch_date_close_approach': 1704594720000,
#                           'miss_distance': {'astronomical': '0.1995347569',
#                                             'kilometers': '29849974.623207803',
#                                             'lunar': '77.6190204341',
#                                             'miles': '18547914.1526535614'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55047.0185348422',
#                                                 'kilometers_per_second': '15.2908384819',
#                                                 'miles_per_hour': '34204.0766001635'}},
#                          {'close_approach_date': '2030-12-04',
#                           'close_approach_date_full': '2030-Dec-04 00:51',
#                           'epoch_date_close_approach': 1922575860000,
#                           'miss_distance': {'astronomical': '0.1367842996',
#                                             'kilometers': '20462639.869601852',
#                                             'lunar': '53.2090925444',
#                                             'miles': '12714894.8174634776'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '54775.8329440082',
#                                                 'kilometers_per_second': '15.2155091511',
#                                                 'miles_per_hour': '34035.5724201256'}},
#                          {'close_approach_date': '2036-08-18',
#                           'close_approach_date_full': '2036-Aug-18 01:49',
#                           'epoch_date_close_approach': 2102636940000,
#                           'miss_distance': {'astronomical': '0.3612697591',
#                                             'kilometers': '54045186.456773117',
#                                             'lunar': '140.5339362899',
#                                             'miles': '33582121.6405663346'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64367.0861516125',
#                                                 'kilometers_per_second': '17.8797461532',
#                                                 'miles_per_hour': '39995.2041701506'}},
#                          {'close_approach_date': '2037-07-17',
#                           'close_approach_date_full': '2037-Jul-17 07:04',
#                           'epoch_date_close_approach': 2131427040000,
#                           'miss_distance': {'astronomical': '0.1342621798',
#                                             'kilometers': '20085336.119637026',
#                                             'lunar': '52.2279879422',
#                                             'miles': '12480449.1386259188'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '45678.602103844',
#                                                 'kilometers_per_second': '12.6885005844',
#                                                 'miles_per_hour': '28382.9069572468'}},
#                          {'close_approach_date': '2037-12-30',
#                           'close_approach_date_full': '2037-Dec-30 12:54',
#                           'epoch_date_close_approach': 2145790440000,
#                           'miss_distance': {'astronomical': '0.3159505527',
#                                             'kilometers': '47265529.709242749',
#                                             'lunar': '122.9047650003',
#                                             'miles': '29369438.2823739762'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '43147.4200516274',
#                                                 'kilometers_per_second': '11.9853944588',
#                                                 'miles_per_hour': '26810.1288648571'}},
#                          {'close_approach_date': '2038-05-29',
#                           'close_approach_date_full': '2038-May-29 09:30',
#                           'epoch_date_close_approach': 2158738200000,
#                           'miss_distance': {'astronomical': '0.3304844317',
#                                             'kilometers': '49439767.050480479',
#                                             'lunar': '128.5584439313',
#                                             'miles': '30720446.7191254502'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '43249.8335813928',
#                                                 'kilometers_per_second': '12.0138426615',
#                                                 'miles_per_hour': '26873.7646495049'}},
#                          {'close_approach_date': '2039-01-09',
#                           'close_approach_date_full': '2039-Jan-09 20:24',
#                           'epoch_date_close_approach': 2178217440000,
#                           'miss_distance': {'astronomical': '0.0444383496',
#                                             'kilometers': '6647882.446475352',
#                                             'lunar': '17.2865179944',
#                                             'miles': '4130802.6043777776'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44690.006417468',
#                                                 'kilometers_per_second': '12.4138906715',
#                                                 'miles_per_hour': '27768.6320431206'}},
#                          {'close_approach_date': '2039-12-31',
#                           'close_approach_date_full': '2039-Dec-31 21:26',
#                           'epoch_date_close_approach': 2208979560000,
#                           'miss_distance': {'astronomical': '0.4116692855',
#                                             'kilometers': '61584848.255221885',
#                                             'lunar': '160.1393520595',
#                                             'miles': '38267050.239096613'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '73629.2395356102',
#                                                 'kilometers_per_second': '20.4525665377',
#                                                 'miles_per_hour': '45750.3460881129'}},
#                          {'close_approach_date': '2048-10-06',
#                           'close_approach_date_full': '2048-Oct-06 16:49',
#                           'epoch_date_close_approach': 2485615740000,
#                           'miss_distance': {'astronomical': '0.1327845021',
#                                             'kilometers': '19864278.683170527',
#                                             'lunar': '51.6531713169',
#                                             'miles': '12343090.4170141926'},
#                           'orbiting_body': 'Venus',
# ...
#                           'close_approach_date_full': '2161-Jan-09 03:47',
#                           'epoch_date_close_approach': 6028141620000,
#                           'miss_distance': {'astronomical': '0.1735726189',
#                                             'kilometers': '25966094.077761743',
#                                             'lunar': '67.5197487521',
#                                             'miles': '16134582.6893803334'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40227.8750662136',
#                                                 'kilometers_per_second': '11.1744097406',
#                                                 'miles_per_hour': '24996.0371487815'}},
#                          {'close_approach_date': '2162-01-08',
#                           'close_approach_date_full': '2162-Jan-08 03:23',
#                           'epoch_date_close_approach': 6059589780000,
#                           'miss_distance': {'astronomical': '0.1941574595',
#                                             'kilometers': '29045542.385811265',
#                                             'lunar': '75.5272517455',
#                                             'miles': '18048063.138734857'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '54618.5434592578',
#                                                 'kilometers_per_second': '15.1718176276',
#                                                 'miles_per_hour': '33937.8388511149'}},
#                          {'close_approach_date': '2174-08-20',
#                           'close_approach_date_full': '2174-Aug-20 16:15',
#                           'epoch_date_close_approach': 6457680900000,
#                           'miss_distance': {'astronomical': '0.3683177582',
#                                             'kilometers': '55099552.109895034',
#                                             'lunar': '143.2756079398',
#                                             'miles': '34237274.0775941092'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64904.6078480639',
#                                                 'kilometers_per_second': '18.0290577356',
#                                                 'miles_per_hour': '40329.1992487039'}},
#                          {'close_approach_date': '2175-06-30',
#                           'close_approach_date_full': '2175-Jun-30 22:13',
#                           'epoch_date_close_approach': 6484831980000,
#                           'miss_distance': {'astronomical': '0.1477959702',
#                                             'kilometers': '22109962.336503474',
#                                             'lunar': '57.4926324078',
#                                             'miles': '13738493.5334929812'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '56314.4217919193',
#                                                 'kilometers_per_second': '15.6428949422',
#                                                 'miles_per_hour': '34991.5916962067'}},
#                          {'close_approach_date': '2175-07-19',
#                           'close_approach_date_full': '2175-Jul-19 20:03',
#                           'epoch_date_close_approach': 6486465780000,
#                           'miss_distance': {'astronomical': '0.1356139766',
#                                             'kilometers': '20287562.041589842',
#                                             'lunar': '52.7538368974',
#                                             'miles': '12606106.4997181396'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '45856.5899290812',
#                                                 'kilometers_per_second': '12.737941647',
#                                                 'miles_per_hour': '28493.5016701005'}},
#                          {'close_approach_date': '2175-12-31',
#                           'close_approach_date_full': '2175-Dec-31 05:52',
#                           'epoch_date_close_approach': 6500670720000,
#                           'miss_distance': {'astronomical': '0.3231269932',
#                                             'kilometers': '48339109.922224484',
#                                             'lunar': '125.6964003548',
#                                             'miles': '30036530.0932625192'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '43216.3205832395',
#                                                 'kilometers_per_second': '12.0045334953',
#                                                 'miles_per_hour': '26852.9409757357'}},
#                          {'close_approach_date': '2176-05-31',
#                           'close_approach_date_full': '2176-May-31 08:01',
#                           'epoch_date_close_approach': 6513811260000,
#                           'miss_distance': {'astronomical': '0.3259506696',
#                                             'kilometers': '48761525.897233752',
#                                             'lunar': '126.7948104744',
#                                             'miles': '30299007.2089076976'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '43425.6417748922',
#                                                 'kilometers_per_second': '12.0626782708',
#                                                 'miles_per_hour': '26983.0050239601'}},
#                          {'close_approach_date': '2177-01-10',
#                           'close_approach_date_full': '2177-Jan-10 18:33',
#                           'epoch_date_close_approach': 6533202780000,
#                           'miss_distance': {'astronomical': '0.0380895033',
#                                             'kilometers': '5698108.563037971',
#                                             'lunar': '14.8168167837',
#                                             'miles': '3540640.4793911598'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44276.9996319293',
#                                                 'kilometers_per_second': '12.2991665644',
#                                                 'miles_per_hour': '27512.0056879618'}},
#                          {'close_approach_date': '2178-01-02',
#                           'close_approach_date_full': '2178-Jan-02 01:44',
#                           'epoch_date_close_approach': 6563987040000,
#                           'miss_distance': {'astronomical': '0.4042977408',
#                                             'kilometers': '60482080.869492096',
#                                             'lunar': '157.2718211712',
#                                             'miles': '37581822.3600430848'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72936.8894991593',
#                                                 'kilometers_per_second': '20.2602470831',
#                                                 'miles_per_hour': '45320.1467001859'}},
#                          {'close_approach_date': '2189-08-27',
#                           'close_approach_date_full': '2189-Aug-27 16:26',
#                           'epoch_date_close_approach': 6931671960000,
#                           'miss_distance': {'astronomical': '0.4536755092',
#                                             'kilometers': '67868889.847485404',
#                                             'lunar': '176.4797730788',
#                                             'miles': '42171772.6201464152'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72547.8434404139',
#                                                 'kilometers_per_second': '20.1521787334',
#                                                 'miles_per_hour': '45078.4086088505'}},
#                          {'close_approach_date': '2190-07-28',
#                           'close_approach_date_full': '2190-Jul-28 20:13',
#                           'epoch_date_close_approach': 6960629580000,
#                           'miss_distance': {'astronomical': '0.1624119676',
#                                             'kilometers': '24296484.415469012',
#                                             'lunar': '63.1782553964',
#                                             'miles': '15097135.3523038856'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '48724.5799421507',
#                                                 'kilometers_per_second': '13.5346055395',
#                                                 'miles_per_hour': '30275.5591312769'}},
#                          {'close_approach_date': '2190-12-18',
#                           'close_approach_date_full': '2190-Dec-18 09:34',
#                           'epoch_date_close_approach': 6972946440000,
#                           'miss_distance': {'astronomical': '0.3991434535',
#                                             'kilometers': '59711010.468044045',
#                                             'lunar': '155.2668034115',
#                                             'miles': '37102701.429716021'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44125.07038366',
#                                                 'kilometers_per_second': '12.2569639955',
#                                                 'miles_per_hour': '27417.6027614469'}},
#                          {'close_approach_date': '2191-06-16',
#                           'close_approach_date_full': '2191-Jun-16 00:29',
#                           'epoch_date_close_approach': 6988465740000,
#                           'miss_distance': {'astronomical': '0.2678453728',
#                                             'kilometers': '40069097.260235936',
#                                             'lunar': '104.1918500192',
#                                             'miles': '24897782.5119944768'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '44358.2423403815',
#                                                 'kilometers_per_second': '12.3217339834',
#                                                 'miles_per_hour': '27562.4867475554'}},
#                          {'close_approach_date': '2192-01-11',
#                           'close_approach_date_full': '2192-Jan-11 20:14',
#                           'epoch_date_close_approach': 7006594440000,
#                           'miss_distance': {'astronomical': '0.0617275945',
#                                             'kilometers': '9234316.657423715',
#                                             'lunar': '24.0120342605',
#                                             'miles': '5737938.299188667'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '41187.0194442432',
#                                                 'kilometers_per_second': '11.4408387345',
#                                                 'miles_per_hour': '25592.0121652299'}},
#                          {'close_approach_date': '2193-01-04',
#                           'close_approach_date_full': '2193-Jan-04 17:11',
#                           'epoch_date_close_approach': 7037601060000,
#                           'miss_distance': {'astronomical': '0.3144833291',
#                                             'kilometers': '47046036.183869017',
#                                             'lunar': '122.3340150199',
#                                             'miles': '29233051.3300537546'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64672.503583122',
#                                                 'kilometers_per_second': '17.9645843286',
#                                                 'miles_per_hour': '40184.978684746'}},
#                          {'close_approach_date': '2193-05-03',
#                           'close_approach_date_full': '2193-May-03 22:09',
#                           'epoch_date_close_approach': 7047900540000,
#                           'miss_distance': {'astronomical': '0.13189988',
#                                             'kilometers': '19731941.1012556',
#                                             'lunar': '51.30905332',
#                                             'miles': '12260859.65670328'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '54040.92511865',
#                                                 'kilometers_per_second': '15.0113680885',
#                                                 'miles_per_hour': '33578.9292771967'}}],
#  'designation': '199003',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 4550.142835581,
#                                  'estimated_diameter_min': 2034.8857375386},
#                         'kilometers': {'estimated_diameter_max': 1.3868834919,
#                                        'estimated_diameter_min': 0.620233153},
#                         'meters': {'estimated_diameter_max': 1386.8834919048,
#                                    'estimated_diameter_min': 620.2331529543},
#                         'miles': {'estimated_diameter_max': 0.8617691822,
#                                   'estimated_diameter_min': 0.3853948945}},
#  'id': '2199003',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2199003?api_key=DEMO_KEY'},
#  'name': '199003 (2005 WJ56)',
#  'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2199003',
#  'neo_reference_id': '2199003',
#  'orbital_data': {'aphelion_distance': '1.105059718905108',
#                   'ascending_node_longitude': '288.0302651181134',
#                   'data_arc_in_days': 6212,
#                   'eccentricity': '.1520773879566815',
#                   'epoch_osculation': '2460000.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '2005-11-29',
#                   'inclination': '21.61395702971058',
#                   'jupiter_tisserand_invariant': '6.214',
#                   'last_observation_date': '2022-12-02',
#                   'mean_anomaly': '297.5320593128592',
#                   'mean_motion': '1.049174991923675',
#                   'minimum_orbit_intersection': '.0225008',
#                   'observations_used': 872,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'similar to that '
#                                                              'of 2062 Aten',
#                                   'orbit_class_range': 'a (semi-major axis) < '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '> 0.983 AU',
#                                   'orbit_class_type': 'ATE'},
#                   'orbit_determination_date': '2022-12-03 05:25:06',
#                   'orbit_id': '174',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '343.1267450818053',
#                   'perihelion_argument': '297.6056595170053',
#                   'perihelion_distance': '.8133178665885823',
#                   'perihelion_time': '2460060.040058777616',
#                   'semi_major_axis': '.9591887927468452'}}

# %% [markdown]
# Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".
#
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
# * use a loop if that is easier to understand - we will look at more compact algorithms to solve this problem in class.
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
# your code here

# %% [markdown]
# ## OPTIONAL - Take your skills to the next level...
# ## Exercise 3
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, which it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
# your code here
