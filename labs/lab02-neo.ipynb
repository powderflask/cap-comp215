# %% [markdown]
# COMP 215 - LAB 2 (NEO)
# ----------------
# #### Name:
# #### Date:
#
# This lab exercise is mostly a review of strings, tuples, lists, dictionaries, and functions.
#
# **Building on new concepts from lab 1**:
#   * `datetime.date` objects represent a calendar date
#   * *list comprehension* provides a compact way to represent map and filter algorithms
#
# **New Python Concepts**:
#   * *f-string* simplifies string formatting operations
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# We'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/)
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# You should register for your own API key, (but may use the DEMO_KEY to get started).
#
# First we need a short tutorial on python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = datetime.date.today()   # get a date object representing today's date
print(today, type(today))
formatted_date = f'Today is: {today}'   # A format string - notice how the variable `today` is formatted into the stringg
print(formatted_date)
# Out:
# 2023-01-11 <class 'datetime.date'>
# Today is: 2023-01-11

# %% [markdown]
# ### Make a query
#
# Let's get some data from the NEO database...
# Here's a query that gets the observation "feed" for today.
# (Note: I hard-coded the date below to lock down the data for the lab - ideally used `today()` so the notebook is always up-to-date.)

# %%
API_KEY = 'DEMO_KEY'  # substitute your API key here

today = '2023-01-09'  #  Future enhancement:  str(datetime.date.today())   # Today's date as a string!
# Use an f-string here to "format" the date and API key varaibles.
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

response = requests.request("GET", url, headers={}, data={})

data = json.loads(response.text)  # recall json.loads for lab 1

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = data['element_count']
neos = data['near_earth_objects'][today]
print(f'{n_results} Near Earth Objects found for {today}')
pprint(neos)
# Out:
# 12 Near Earth Objects found for 2023-01-09
# [{'absolute_magnitude_h': 19.64,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 13:59',
#                            'epoch_date_close_approach': 1673272740000,
#                            'miss_distance': {'astronomical': '0.0725377631',
#                                              'kilometers': '10851494.854324597',
#                                              'lunar': '28.2171898459',
#                                              'miles': '6742806.2343975586'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '32387.3201949256',
#                                                  'kilometers_per_second': '8.9964778319',
#                                                  'miles_per_hour': '20124.2212622303'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 2301.5744618737,
#                                   'estimated_diameter_min': 1029.2953904054},
#                          'kilometers': {'estimated_diameter_max': 0.7015198735,
#                                         'estimated_diameter_min': 0.313729225},
#                          'meters': {'estimated_diameter_max': 701.5198735305,
#                                     'estimated_diameter_min': 313.7292249562},
#                          'miles': {'estimated_diameter_max': 0.4359041053,
#                                    'estimated_diameter_min': 0.1949422422}},
#   'id': '2226554',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=DEMO_KEY'},
#   'name': '226554 (2003 WR21)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2226554',
#   'neo_reference_id': '2226554'},
#  {'absolute_magnitude_h': 20.62,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 16:33',
#                            'epoch_date_close_approach': 1673281980000,
#                            'miss_distance': {'astronomical': '0.2884780108',
#                                              'kilometers': '43155695.957516996',
#                                              'lunar': '112.2179462012',
#                                              'miles': '26815706.0071907048'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '30014.4391606086',
#                                                  'kilometers_per_second': '8.3373442113',
#                                                  'miles_per_hour': '18649.8052662126'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1465.6323083572,
#                                   'estimated_diameter_min': 655.4506943013},
#                          'kilometers': {'estimated_diameter_max': 0.4467247133,
#                                         'estimated_diameter_min': 0.1997813652},
#                          'meters': {'estimated_diameter_max': 446.7247132921,
#                                     'estimated_diameter_min': 199.78136523},
#                          'miles': {'estimated_diameter_max': 0.2775817818,
#                                    'estimated_diameter_min': 0.1241383467}},
#   'id': '2307070',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2307070?api_key=DEMO_KEY'},
#   'name': '307070 (2002 AV31)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2307070',
#   'neo_reference_id': '2307070'},
#  {'absolute_magnitude_h': 18.4,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 01:00',
#                            'epoch_date_close_approach': 1673226000000,
#                            'miss_distance': {'astronomical': '0.3628965299',
#                                              'kilometers': '54288547.903431313',
#                                              'lunar': '141.1667501311',
#                                              'miles': '33733339.4314575994'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '88002.1188429376',
#                                                  'kilometers_per_second': '24.4450330119',
#                                                  'miles_per_hour': '54681.0943443797'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 4074.0375731972,
#                                   'estimated_diameter_min': 1821.9649913114},
#                          'kilometers': {'estimated_diameter_max': 1.2417666126,
#                                         'estimated_diameter_min': 0.5553349116},
#                          'meters': {'estimated_diameter_max': 1241.766612574,
#                                     'estimated_diameter_min': 555.334911581},
#                          'miles': {'estimated_diameter_max': 0.7715977618,
#                                    'estimated_diameter_min': 0.3450690093}},
#   'id': '2436325',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2436325?api_key=DEMO_KEY'},
#   'name': '436325 (2010 GR7)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2436325',
#   'neo_reference_id': '2436325'},
#  {'absolute_magnitude_h': 20.96,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 03:24',
#                            'epoch_date_close_approach': 1673234640000,
#                            'miss_distance': {'astronomical': '0.1211162012',
#                                              'kilometers': '18118725.722011444',
#                                              'lunar': '47.1142022668',
#                                              'miles': '11258454.1022041672'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '22658.3508544674',
#                                                  'kilometers_per_second': '6.2939863485',
#                                                  'miles_per_hour': '14079.0180628772'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1253.2134002046,
#                                   'estimated_diameter_min': 560.4540706342},
#                          'kilometers': {'estimated_diameter_max': 0.3819794322,
#                                         'estimated_diameter_min': 0.1708263953},
#                          'meters': {'estimated_diameter_max': 381.979432159,
#                                     'estimated_diameter_min': 170.8263952629},
#                          'miles': {'estimated_diameter_max': 0.2373509417,
#                                    'estimated_diameter_min': 0.1061465681}},
#   'id': '2508908',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2508908?api_key=DEMO_KEY'},
#   'name': '508908 (2003 YX1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2508908',
#   'neo_reference_id': '2508908'},
#  {'absolute_magnitude_h': 21.3,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 07:10',
#                            'epoch_date_close_approach': 1673248200000,
#                            'miss_distance': {'astronomical': '0.4928732055',
#                                              'kilometers': '73732781.722872285',
#                                              'lunar': '191.7276769395',
#                                              'miles': '45815426.073056133'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '121198.8588141982',
#                                                  'kilometers_per_second': '33.6663496706',
#                                                  'miles_per_hour': '75308.2575781889'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1071.581062656,
#                                   'estimated_diameter_min': 479.2256199},
#                          'kilometers': {'estimated_diameter_max': 0.3266178974,
#                                         'estimated_diameter_min': 0.1460679643},
#                          'meters': {'estimated_diameter_max': 326.6178974458,
#                                     'estimated_diameter_min': 146.0679642714},
#                          'miles': {'estimated_diameter_max': 0.2029508896,
#                                    'estimated_diameter_min': 0.090762397}},
#   'id': '3014110',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3014110?api_key=DEMO_KEY'},
#   'name': '(1998 SU4)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3014110',
#   'neo_reference_id': '3014110'},
#  {'absolute_magnitude_h': 25.2,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 23:16',
#                            'epoch_date_close_approach': 1673306160000,
#                            'miss_distance': {'astronomical': '0.0850918498',
#                                              'kilometers': '12729559.484439926',
#                                              'lunar': '33.1007295722',
#                                              'miles': '7909781.4821899388'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '36346.123842818',
#                                                  'kilometers_per_second': '10.0961455119',
#                                                  'miles_per_hour': '22584.0678955555'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 177.8381901842,
#                                   'estimated_diameter_min': 79.5316564495},
#                          'kilometers': {'estimated_diameter_max': 0.0542050786,
#                                         'estimated_diameter_min': 0.0242412481},
#                          'meters': {'estimated_diameter_max': 54.2050786336,
#                                     'estimated_diameter_min': 24.2412481101},
#                          'miles': {'estimated_diameter_max': 0.0336814639,
#                                    'estimated_diameter_min': 0.0150628086}},
#   'id': '3559843',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3559843?api_key=DEMO_KEY'},
#   'name': '(2011 EP51)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3559843',
#   'neo_reference_id': '3559843'},
#  {'absolute_magnitude_h': 26.9,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:16',
#                            'epoch_date_close_approach': 1673273760000,
#                            'miss_distance': {'astronomical': '0.4272893529',
#                                              'kilometers': '63921577.067518323',
#                                              'lunar': '166.2155582781',
#                                              'miles': '39719026.1940379374'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '16576.4865892554',
#                                                  'kilometers_per_second': '4.6045796081',
#                                                  'miles_per_hour': '10299.9841254181'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 81.2877363957,
#                                   'estimated_diameter_min': 36.3529808636},
#                          'kilometers': {'estimated_diameter_max': 0.0247765013,
#                                         'estimated_diameter_min': 0.0110803882},
#                          'meters': {'estimated_diameter_max': 24.7765012606,
#                                     'estimated_diameter_min': 11.0803882126},
#                          'miles': {'estimated_diameter_max': 0.0153953994,
#                                    'estimated_diameter_min': 0.0068850319}},
#   'id': '3789481',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3789481?api_key=DEMO_KEY'},
#   'name': '(2017 WU1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3789481',
#   'neo_reference_id': '3789481'},
#  {'absolute_magnitude_h': 25.4,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 04:18',
#                            'epoch_date_close_approach': 1673237880000,
#                            'miss_distance': {'astronomical': '0.4741066959',
#                                              'kilometers': '70925351.859377733',
#                                              'lunar': '184.4275047051',
#                                              'miles': '44070970.0473813954'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '71419.4248076035',
#                                                  'kilometers_per_second': '19.8387291132',
#                                                  'miles_per_hour': '44377.253153369'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 162.1903570994,
#                                   'estimated_diameter_min': 72.5337327539},
#                          'kilometers': {'estimated_diameter_max': 0.0494356193,
#                                         'estimated_diameter_min': 0.022108281},
#                          'meters': {'estimated_diameter_max': 49.435619262,
#                                     'estimated_diameter_min': 22.1082810359},
#                          'miles': {'estimated_diameter_max': 0.0307178602,
#                                    'estimated_diameter_min': 0.0137374447}},
#   'id': '54054562',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54054562?api_key=DEMO_KEY'},
#   'name': '(2020 SA3)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054562',
#   'neo_reference_id': '54054562'},
#  {'absolute_magnitude_h': 26.1,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:29',
#                            'epoch_date_close_approach': 1673274540000,
#                            'miss_distance': {'astronomical': '0.3334722534',
#                                              'kilometers': '49886738.812740258',
#                                              'lunar': '129.7207065726',
#                                              'miles': '30998182.0934332404'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '60765.8145388754',
#                                                  'kilometers_per_second': '16.8793929275',
#                                                  'miles_per_hour': '37757.5140394474'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 117.4965270602,
#                                   'estimated_diameter_min': 52.5460443254},
#                          'kilometers': {'estimated_diameter_max': 0.0358129403,
#                                         'estimated_diameter_min': 0.0160160338},
#                          'meters': {'estimated_diameter_max': 35.8129403019,
#                                     'estimated_diameter_min': 16.0160337979},
#                          'miles': {'estimated_diameter_max': 0.0222531225,
#                                    'estimated_diameter_min': 0.0099518989}},
#   'id': '54104276',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54104276?api_key=DEMO_KEY'},
#   'name': '(2021 AA1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54104276',
#   'neo_reference_id': '54104276'},
#  {'absolute_magnitude_h': 27.2,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:50',
#                            'epoch_date_close_approach': 1673275800000,
#                            'miss_distance': {'astronomical': '0.1503150963',
#                                              'kilometers': '22486818.235324881',
#                                              'lunar': '58.4725724607',
#                                              'miles': '13972660.9305341178'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '33590.9419665386',
#                                                  'kilometers_per_second': '9.3308172129',
#                                                  'miles_per_hour': '20872.1050235973'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 70.7986587106,
#                                   'estimated_diameter_min': 31.6621227185},
#                          'kilometers': {'estimated_diameter_max': 0.0215794305,
#                                         'estimated_diameter_min': 0.0096506147},
#                          'meters': {'estimated_diameter_max': 21.5794304844,
#                                     'estimated_diameter_min': 9.6506146958},
#                          'miles': {'estimated_diameter_max': 0.0134088323,
#                                    'estimated_diameter_min': 0.0059966121}},
#   'id': '54130489',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54130489?api_key=DEMO_KEY'},
#   'name': '(2021 EP1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54130489',
#   'neo_reference_id': '54130489'},
#  {'absolute_magnitude_h': 23.39,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 23:18',
#                            'epoch_date_close_approach': 1673306280000,
#                            'miss_distance': {'astronomical': '0.1990572251',
#                                              'kilometers': '29778536.883070537',
#                                              'lunar': '77.4332605639',
#                                              'miles': '18503524.7992939306'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '42454.2341018916',
#                                                  'kilometers_per_second': '11.7928428061',
#                                                  'miles_per_hour': '26379.4100729226'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 409.2842476221,
#                                   'estimated_diameter_min': 183.0374799606},
#                          'kilometers': {'estimated_diameter_max': 0.1247498347,
#                                         'estimated_diameter_min': 0.0557898221},
#                          'meters': {'estimated_diameter_max': 124.7498346832,
#                                     'estimated_diameter_min': 55.7898221067},
#                          'miles': {'estimated_diameter_max': 0.0775159295,
#                                    'estimated_diameter_min': 0.0346661776}},
#   'id': '54174525',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54174525?api_key=DEMO_KEY'},
#   'name': '(2021 OZ)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54174525',
#   'neo_reference_id': '54174525'},
#  {'absolute_magnitude_h': 23.39,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 05:43',
#                            'epoch_date_close_approach': 1673242980000,
#                            'miss_distance': {'astronomical': '0.0364120775',
#                                              'kilometers': '5447169.236274925',
#                                              'lunar': '14.1642981475',
#                                              'miles': '3384714.012146965'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '30422.1248161603',
#                                                  'kilometers_per_second': '8.4505902267',
#                                                  'miles_per_hour': '18903.1252781303'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 409.2842476221,
#                                   'estimated_diameter_min': 183.0374799606},
#                          'kilometers': {'estimated_diameter_max': 0.1247498347,
#                                         'estimated_diameter_min': 0.0557898221},
#                          'meters': {'estimated_diameter_max': 124.7498346832,
#                                     'estimated_diameter_min': 55.7898221067},
#                          'miles': {'estimated_diameter_max': 0.0775159295,
#                                    'estimated_diameter_min': 0.0346661776}},
#   'id': '54201812',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54201812?api_key=DEMO_KEY'},
#   'name': '(2021 TL)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54201812',
#   'neo_reference_id': '54201812'}]

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a Comp115-style list accumulator *loop*:

# %%
hazards =  []
for item in neos:
  if item['is_potentially_hazardous_asteroid'] is True:
    hazards.append(item)
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 3 potentially hazardous asteroids identified.

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the accumulator loop above** as a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0)
# Notice how this provides a concise way to "filter" items of interest from a larger data set.

# %%
# Your code here

# %% [markdown]
# ## Fetch Complete Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the first hazardous asteroid...

# %%
id = hazards[0]['id']
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

pprint(data)
# Out:
# {'absolute_magnitude_h': 19.64,
#  'close_approach_data': [{'close_approach_date': '1900-10-30',
#                           'close_approach_date_full': '1900-Oct-30 21:14',
#                           'epoch_date_close_approach': -2182819560000,
#                           'miss_distance': {'astronomical': '0.4183490942',
#                                             'kilometers': '62584133.408749354',
#                                             'lunar': '162.7377976438',
#                                             'miles': '38887977.2407309252'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30027.9669430086',
#                                                 'kilometers_per_second': '8.3411019286',
#                                                 'miles_per_hour': '18658.2109041156'}},
#                          {'close_approach_date': '1901-06-26',
#                           'close_approach_date_full': '1901-Jun-26 20:27',
#                           'epoch_date_close_approach': -2162172780000,
#                           'miss_distance': {'astronomical': '0.0308800166',
#                                             'kilometers': '4619584.708924642',
#                                             'lunar': '12.0123264574',
#                                             'miles': '2870476.8323463796'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33429.0818456076',
#                                                 'kilometers_per_second': '9.2858560682',
#                                                 'miles_per_hour': '20771.531439011'}},
#                          {'close_approach_date': '1907-01-08',
#                           'close_approach_date_full': '1907-Jan-08 04:37',
#                           'epoch_date_close_approach': -1987528980000,
#                           'miss_distance': {'astronomical': '0.1240279479',
#                                             'kilometers': '18554316.826310973',
#                                             'lunar': '48.2468717331',
#                                             'miles': '11529117.8635705074'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24041.8672591713',
#                                                 'kilometers_per_second': '6.6782964609',
#                                                 'miles_per_hour': '14938.6813533445'}},
#                          {'close_approach_date': '1907-09-06',
#                           'close_approach_date_full': '1907-Sep-06 10:51',
#                           'epoch_date_close_approach': -1966684140000,
#                           'miss_distance': {'astronomical': '0.4147266871',
#                                             'kilometers': '62042229.022316477',
#                                             'lunar': '161.3286812819',
#                                             'miles': '38551253.4690903026'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26520.2058909168',
#                                                 'kilometers_per_second': '7.3667238586',
#                                                 'miles_per_hour': '16478.6245992755'}},
#                          {'close_approach_date': '1909-08-06',
#                           'close_approach_date_full': '1909-Aug-06 06:41',
#                           'epoch_date_close_approach': -1906219140000,
#                           'miss_distance': {'astronomical': '0.1317213696',
#                                             'kilometers': '19705236.325642752',
#                                             'lunar': '51.2396127744',
#                                             'miles': '12244266.0785918976'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7812.3440031327',
#                                                 'kilometers_per_second': '2.1700955564',
#                                                 'miles_per_hour': '4854.2867501688'}},
#                          {'close_approach_date': '1912-12-22',
#                           'close_approach_date_full': '1912-Dec-22 20:01',
#                           'epoch_date_close_approach': -1799553540000,
#                           'miss_distance': {'astronomical': '0.4621515936',
#                                             'kilometers': '69136894.019665632',
#                                             'lunar': '179.7769699104',
#                                             'miles': '42959673.8772724416'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78890.0991792962',
#                                                 'kilometers_per_second': '21.9139164387',
#                                                 'miles_per_hour': '49019.2396817133'}},
#                          {'close_approach_date': '1913-10-29',
#                           'close_approach_date_full': '1913-Oct-29 19:08',
#                           'epoch_date_close_approach': -1772686320000,
#                           'miss_distance': {'astronomical': '0.4230472471',
#                                             'kilometers': '63286967.075523677',
#                                             'lunar': '164.5653791219',
#                                             'miles': '39324697.8302616626'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30216.1899383883',
#                                                 'kilometers_per_second': '8.393386094',
#                                                 'miles_per_hour': '18775.1653536613'}},
#                          {'close_approach_date': '1914-06-28',
#                           'close_approach_date_full': '1914-Jun-28 14:48',
#                           'epoch_date_close_approach': -1751793120000,
#                           'miss_distance': {'astronomical': '0.0438417366',
#                                             'kilometers': '6558630.412461042',
#                                             'lunar': '17.0544355374',
#                                             'miles': '4075343.9620926996'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '35202.9120507459',
#                                                 'kilometers_per_second': '9.7785866808',
#                                                 'miles_per_hour': '21873.7205461982'}},
#                          {'close_approach_date': '1919-12-30',
#                           'close_approach_date_full': '1919-Dec-30 11:27',
#                           'epoch_date_close_approach': -1578054780000,
#                           'miss_distance': {'astronomical': '0.1880323474',
#                                             'kilometers': '28129238.662140038',
#                                             'lunar': '73.1445831386',
#                                             'miles': '17478698.4066390044'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22319.4418824565',
#                                                 'kilometers_per_second': '6.1998449673',
#                                                 'miles_per_hour': '13868.4332074631'}},
#                          {'close_approach_date': '1920-02-20',
#                           'close_approach_date_full': '1920-Feb-20 02:12',
#                           'epoch_date_close_approach': -1573595280000,
#                           'miss_distance': {'astronomical': '0.2016985227',
#                                             'kilometers': '30173669.378066649',
#                                             'lunar': '78.4607253303',
#                                             'miles': '18749048.7465877962'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18955.9960160327',
#                                                 'kilometers_per_second': '5.2655544489',
#                                                 'miles_per_hour': '11778.5187467399'}},
#                          {'close_approach_date': '1920-08-27',
#                           'close_approach_date_full': '1920-Aug-27 00:15',
#                           'epoch_date_close_approach': -1557272700000,
#                           'miss_distance': {'astronomical': '0.3922387373',
#                                             'kilometers': '58678079.631569551',
#                                             'lunar': '152.5808688097',
#                                             'miles': '36460867.9701437638'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24779.6376577082',
#                                                 'kilometers_per_second': '6.8832326827',
#                                                 'miles_per_hour': '15397.1031879243'}},
#                          {'close_approach_date': '1924-12-19',
#                           'close_approach_date_full': '1924-Dec-19 14:33',
#                           'epoch_date_close_approach': -1421141220000,
#                           'miss_distance': {'astronomical': '0.1361639066',
#                                             'kilometers': '20369830.398238942',
#                                             'lunar': '52.9677596674',
#                                             'miles': '12657225.6861117196'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '7522.1198197348',
#                                                 'kilometers_per_second': '2.0894777277',
#                                                 'miles_per_hour': '4673.9527291013'}},
#                          {'close_approach_date': '1925-12-28',
#                           'close_approach_date_full': '1925-Dec-28 17:32',
#                           'epoch_date_close_approach': -1388816880000,
#                           'miss_distance': {'astronomical': '0.3364577156',
#                                             'kilometers': '50333357.598825772',
#                                             'lunar': '130.8820513684',
#                                             'miles': '31275698.1385167736'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '65215.5644556904',
#                                                 'kilometers_per_second': '18.115434571',
#                                                 'miles_per_hour': '40522.415591926'}},
#                          {'close_approach_date': '1926-10-17',
#                           'close_approach_date_full': '1926-Oct-17 17:33',
#                           'epoch_date_close_approach': -1363501620000,
#                           'miss_distance': {'astronomical': '0.4449024522',
#                                             'kilometers': '66556459.206896814',
#                                             'lunar': '173.0670539058',
#                                             'miles': '41356266.0356274732'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30428.2147478072',
#                                                 'kilometers_per_second': '8.4522818744',
#                                                 'miles_per_hour': '18906.909324825'}},
#                          {'close_approach_date': '1927-07-07',
#                           'close_approach_date_full': '1927-Jul-07 13:10',
#                           'epoch_date_close_approach': -1340794200000,
#                           'miss_distance': {'astronomical': '0.1746956792',
#                                             'kilometers': '26134101.506523304',
#                                             'lunar': '67.9566192088',
#                                             'miles': '16238977.6647534352'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '48367.3443447701',
#                                                 'kilometers_per_second': '13.4353734291',
#                                                 'miles_per_hour': '30053.5868235601'}},
#                          {'close_approach_date': '1932-12-06',
#                           'close_approach_date_full': '1932-Dec-06 07:38',
#                           'epoch_date_close_approach': -1169828520000,
#                           'miss_distance': {'astronomical': '0.29496135',
#                                             'kilometers': '44125589.6923245',
#                                             'lunar': '114.73996515',
#                                             'miles': '27418370.0280981'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25801.9058671476',
#                                                 'kilometers_per_second': '7.1671960742',
#                                                 'miles_per_hour': '16032.3008983951'}},
#                          {'close_approach_date': '1933-04-15',
#                           'close_approach_date_full': '1933-Apr-15 01:31',
#                           'epoch_date_close_approach': -1158618540000,
#                           'miss_distance': {'astronomical': '0.2180165371',
#                                             'kilometers': '32614809.574935977',
#                                             'lunar': '84.8084329319',
#                                             'miles': '20265902.9274594026'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26552.3331595608',
#                                                 'kilometers_per_second': '7.3756480999',
#                                                 'miles_per_hour': '16498.5872346171'}},
#                          {'close_approach_date': '1933-07-30',
#                           'close_approach_date_full': '1933-Jul-30 19:07',
#                           'epoch_date_close_approach': -1149396780000,
#                           'miss_distance': {'astronomical': '0.3178404702',
#                                             'kilometers': '47548257.341718474',
#                                             'lunar': '123.6399429078',
#                                             'miles': '29545117.0868599812'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19585.9801316298',
#                                                 'kilometers_per_second': '5.4405500366',
#                                                 'miles_per_hour': '12169.9663767896'}},
#                          {'close_approach_date': '1939-01-04',
#                           'close_approach_date_full': '1939-Jan-04 13:15',
#                           'epoch_date_close_approach': -978000300000,
#                           'miss_distance': {'astronomical': '0.1772562474',
#                                             'kilometers': '26517157.055233038',
#                                             'lunar': '68.9526802386',
#                                             'miles': '16476997.3456024044'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '47802.8925574816',
#                                                 'kilometers_per_second': '13.278581266',
#                                                 'miles_per_hour': '29702.8584338418'}},
#                          {'close_approach_date': '1939-10-02',
#                           'close_approach_date_full': '1939-Oct-02 23:41',
#                           'epoch_date_close_approach': -954548340000,
#                           'miss_distance': {'astronomical': '0.4508022946',
#                                             'kilometers': '67439063.063272502',
#                                             'lunar': '175.3620925994',
#                                             'miles': '41904690.6411924476'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29767.9955940415',
#                                                 'kilometers_per_second': '8.268887665',
#                                                 'miles_per_hour': '18496.6748178643'}},
#                          {'close_approach_date': '1940-07-15',
#                           'close_approach_date_full': '1940-Jul-15 08:32',
#                           'epoch_date_close_approach': -929806080000,
#                           'miss_distance': {'astronomical': '0.3345311533',
#                                             'kilometers': '50045147.982323471',
#                                             'lunar': '130.1326186337',
#                                             'miles': '31096612.9871110598'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '64571.2379105717',
#                                                 'kilometers_per_second': '17.9364549752',
#                                                 'miles_per_hour': '40122.0561339327'}},
#                          {'close_approach_date': '1945-11-18',
#                           'close_approach_date_full': '1945-Nov-18 06:11',
#                           'epoch_date_close_approach': -761161740000,
#                           'miss_distance': {'astronomical': '0.368752203',
#                                             'kilometers': '55164544.12660761',
#                                             'lunar': '143.444606967',
#                                             'miles': '34277658.244140618'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28578.6800945402',
#                                                 'kilometers_per_second': '7.9385222485',
#                                                 'miles_per_hour': '17757.6804176325'}},
#                          {'close_approach_date': '1946-05-31',
#                           'close_approach_date_full': '1946-May-31 01:44',
#                           'epoch_date_close_approach': -744416160000,
#                           'miss_distance': {'astronomical': '0.1446828194',
#                                             'kilometers': '21644241.607834678',
#                                             'lunar': '56.2816167466',
#                                             'miles': '13449108.0916794364'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24131.1529559109',
#                                                 'kilometers_per_second': '6.7030980433',
#                                                 'miles_per_hour': '14994.160013077'}},
#                          {'close_approach_date': '1952-01-09',
#                           'close_approach_date_full': '1952-Jan-09 10:55',
#                           'epoch_date_close_approach': -567349500000,
#                           'miss_distance': {'astronomical': '0.0732962523',
#                                             'kilometers': '10964963.223062601',
#                                             'lunar': '28.5122421447',
#                                             'miles': '6813312.2093258538'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33228.764002551',
#                                                 'kilometers_per_second': '9.2302122229',
#                                                 'miles_per_hour': '20647.061721474'}},
#                          {'close_approach_date': '1952-09-18',
#                           'close_approach_date_full': '1952-Sep-18 12:09',
#                           'epoch_date_close_approach': -545485860000,
#                           'miss_distance': {'astronomical': '0.4381151784',
#                                             'kilometers': '65541097.503310008',
#                                             'lunar': '170.4268043976',
#                                             'miles': '40725349.5290057904'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28395.3041655',
#                                                 'kilometers_per_second': '7.8875844904',
#                                                 'miles_per_hour': '17643.737746613'}},
#                          {'close_approach_date': '1953-07-22',
#                           'close_approach_date_full': '1953-Jul-22 08:41',
#                           'epoch_date_close_approach': -518973540000,
#                           'miss_distance': {'astronomical': '0.4679425314',
#                                             'kilometers': '70003205.979848118',
#                                             'lunar': '182.0296447146',
#                                             'miles': '43497975.1679673084'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78392.9660611212',
#                                                 'kilometers_per_second': '21.7758239059',
#                                                 'miles_per_hour': '48710.3404950339'}},
#                          {'close_approach_date': '1958-11-06',
#                           'close_approach_date_full': '1958-Nov-06 23:01',
#                           'epoch_date_close_approach': -351910740000,
#                           'miss_distance': {'astronomical': '0.40521612',
#                                             'kilometers': '60619468.4416644',
#                                             'lunar': '157.62907068',
#                                             'miles': '37667191.03879272'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29821.8751143841',
#                                                 'kilometers_per_second': '8.2838541984',
#                                                 'miles_per_hour': '18530.1534564905'}},
#                          {'close_approach_date': '1959-06-22',
#                           'close_approach_date_full': '1959-Jun-22 11:57',
#                           'epoch_date_close_approach': -332251380000,
#                           'miss_distance': {'astronomical': '0.0488517924',
#                                             'kilometers': '7308124.088722188',
#                                             'lunar': '19.0033472436',
#                                             'miles': '4541057.7370866744'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28870.6740507818',
#                                                 'kilometers_per_second': '8.0196316808',
#                                                 'miles_per_hour': '17939.1141067205'}},
#                          {'close_approach_date': '1965-01-09',
#                           'close_approach_date_full': '1965-Jan-09 06:20',
#                           'epoch_date_close_approach': -157052400000,
#                           'miss_distance': {'astronomical': '0.0918939828',
#                                             'kilometers': '13747144.092696636',
#                                             'lunar': '35.7467593092',
#                                             'miles': '8542079.2377241368'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27010.5030006695',
#                                                 'kilometers_per_second': '7.5029175002',
#                                                 'miles_per_hour': '16783.276156166'}},
#                          {'close_approach_date': '1965-09-11',
#                           'close_approach_date_full': '1965-Sep-11 11:07',
#                           'epoch_date_close_approach': -135867180000,
#                           'miss_distance': {'astronomical': '0.4256121996',
#                                             'kilometers': '63670678.506174852',
#                                             'lunar': '165.5631456444',
#                                             'miles': '39563125.0572508776'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27282.9323174596',
#                                                 'kilometers_per_second': '7.5785923104',
#                                                 'miles_per_hour': '16952.5531391459'}},
#                          {'close_approach_date': '1970-12-22',
#                           'close_approach_date_full': '1970-Dec-22 03:21',
#                           'epoch_date_close_approach': 30684060000,
#                           'miss_distance': {'astronomical': '0.4970943439',
#                                             'kilometers': '74364255.036487493',
#                                             'lunar': '193.3696997771',
#                                             'miles': '46207805.3952656834'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '82786.1148705247',
#                                                 'kilometers_per_second': '22.9961430196',
#                                                 'miles_per_hour': '51440.0723205213'}},
#                          {'close_approach_date': '1971-11-02',
#                           'close_approach_date_full': '1971-Nov-02 20:26',
#                           'epoch_date_close_approach': 57961560000,
#                           'miss_distance': {'astronomical': '0.4161213848',
#                                             'kilometers': '62250872.827530376',
#                                             'lunar': '161.8712186872',
#                                             'miles': '38680898.7179201488'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30031.6597747765',
#                                                 'kilometers_per_second': '8.3421277152',
#                                                 'miles_per_hour': '18660.505486166'}},
#                          {'close_approach_date': '1972-06-25',
#                           'close_approach_date_full': '1972-Jun-25 18:40',
#                           'epoch_date_close_approach': 78345600000,
#                           'miss_distance': {'astronomical': '0.02876926',
#                                             'kilometers': '4303820.0174762',
#                                             'lunar': '11.19124214',
#                                             'miles': '2674269.75132356'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32284.6523957868',
#                                                 'kilometers_per_second': '8.9679589988',
#                                                 'miles_per_hour': '20060.4274844821'}},
#                          {'close_approach_date': '1978-01-06',
#                           'close_approach_date_full': '1978-Jan-06 06:31',
#                           'epoch_date_close_approach': 252916260000,
#                           'miss_distance': {'astronomical': '0.1452309931',
#                                             'kilometers': '21726247.225744697',
#                                             'lunar': '56.4948563159',
#                                             'miles': '13500064.0197909386'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22857.4879787721',
#                                                 'kilometers_per_second': '6.3493022163',
#                                                 'miles_per_hour': '14202.7541276987'}},
#                          {'close_approach_date': '1978-09-03',
#                           'close_approach_date_full': '1978-Sep-03 16:17',
#                           'epoch_date_close_approach': 273687420000,
#                           'miss_distance': {'astronomical': '0.4089771228',
#                                             'kilometers': '61182106.449608436',
#                                             'lunar': '159.0921007692',
#                                             'miles': '38016798.0854349768'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26109.7514453104',
#                                                 'kilometers_per_second': '7.2527087348',
#                                                 'miles_per_hour': '16223.584168893'}},
#                          {'close_approach_date': '1983-12-26',
#                           'close_approach_date_full': '1983-Dec-26 09:46',
#                           'epoch_date_close_approach': 441279960000,
#                           'miss_distance': {'astronomical': '0.4048346262',
#                                             'kilometers': '60562397.781766194',
#                                             'lunar': '157.4806695918',
#                                             'miles': '37631728.9751297172'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '72737.7597197446',
#                                                 'kilometers_per_second': '20.2049332555',
#                                                 'miles_per_hour': '45196.4151991935'}},
#                          {'close_approach_date': '1984-10-24',
#                           'close_approach_date_full': '1984-Oct-24 02:43',
#                           'epoch_date_close_approach': 467433780000,
#                           'miss_distance': {'astronomical': '0.4350098854',
#                                             'kilometers': '65076552.284784098',
#                                             'lunar': '169.2188454206',
#                                             'miles': '40436694.5153246324'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30503.8947106261',
#                                                 'kilometers_per_second': '8.4733040863',
#                                                 'miles_per_hour': '18953.933910611'}},
#                          {'close_approach_date': '1985-07-02',
#                           'close_approach_date_full': '1985-Jul-02 21:01',
#                           'epoch_date_close_approach': 489186060000,
#                           'miss_distance': {'astronomical': '0.1010070268',
#                                             'kilometers': '15110436.064312916',
#                                             'lunar': '39.2917334252',
#                                             'miles': '9389189.5878576008'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '40996.5603823066',
#                                                 'kilometers_per_second': '11.3879334395',
#                                                 'miles_per_hour': '25473.6683108838'}},
#                          {'close_approach_date': '1990-12-18',
#                           'close_approach_date_full': '1990-Dec-18 07:59',
#                           'epoch_date_close_approach': 661507140000,
#                           'miss_distance': {'astronomical': '0.2439796196',
#                                             'kilometers': '36498831.415570252',
#                                             'lunar': '94.9080720244',
#                                             'miles': '22679322.1874913976'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23867.3981742309',
#                                                 'kilometers_per_second': '6.6298328262',
#                                                 'miles_per_hour': '14830.2730488714'}},
#                          {'close_approach_date': '1991-03-23',
#                           'close_approach_date_full': '1991-Mar-23 17:01',
#                           'epoch_date_close_approach': 669747660000,
#                           'miss_distance': {'astronomical': '0.2222873546',
#                                             'kilometers': '33253714.776094702',
#                                             'lunar': '86.4697809394',
#                                             'miles': '20662900.2104508076'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24935.8824683001',
#                                                 'kilometers_per_second': '6.926634019',
#                                                 'miles_per_hour': '15494.187637039'}},
#                          {'close_approach_date': '1991-08-17',
#                           'close_approach_date_full': '1991-Aug-17 15:32',
#                           'epoch_date_close_approach': 682443120000,
#                           'miss_distance': {'astronomical': '0.3635087788',
#                                             'kilometers': '54380139.034781156',
#                                             'lunar': '141.4049149532',
#                                             'miles': '33790251.5214297128'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22827.8939470546',
#                                                 'kilometers_per_second': '6.341081652',
#                                                 'miles_per_hour': '14184.3655472685'}},
#                          {'close_approach_date': '1996-12-31',
#                           'close_approach_date_full': '1996-Dec-31 18:58',
#                           'epoch_date_close_approach': 852058680000,
#                           'miss_distance': {'astronomical': '0.2617186492',
#                                             'kilometers': '39152552.459597204',
#                                             'lunar': '101.8085545388',
#                                             'miles': '24328267.9816172552'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '57151.754407318',
#                                                 'kilometers_per_second': '15.8754873354',
#                                                 'miles_per_hour': '35511.8776204804'}},
#                          {'close_approach_date': '1997-10-10',
#                           'close_approach_date_full': '1997-Oct-10 21:51',
#                           'epoch_date_close_approach': 876520260000,
#                           'miss_distance': {'astronomical': '0.4499913031',
#                                             'kilometers': '67317740.462284397',
#                                             'lunar': '175.0466169059',
#                                             'miles': '41829304.2726507986'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30320.8910826904',
#                                                 'kilometers_per_second': '8.4224697452',
#                                                 'miles_per_hour': '18840.2225730195'}},
#                          {'close_approach_date': '1998-07-11',
#                           'close_approach_date_full': '1998-Jul-11 12:30',
#                           'epoch_date_close_approach': 900160200000,
#                           'miss_distance': {'astronomical': '0.2461740856',
#                                             'kilometers': '36827118.854957672',
#                                             'lunar': '95.7617192984',
#                                             'miles': '22883310.5432609936'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '55503.2897002325',
#                                                 'kilometers_per_second': '15.4175804723',
#                                                 'miles_per_hour': '34487.5857584583'}},
#                          {'close_approach_date': '2003-02-15',
#                           'close_approach_date_full': '2003-Feb-15 17:49',
#                           'epoch_date_close_approach': 1045331340000,
#                           'miss_distance': {'astronomical': '0.1392391396',
#                                             'kilometers': '20829878.704792652',
#                                             'lunar': '54.1640253044',
#                                             'miles': '12943086.4482645176'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8396.5701004877',
#                                                 'kilometers_per_second': '2.3323805835',
#                                                 'miles_per_hour': '5217.3021271614'}},
#                          {'close_approach_date': '2003-11-28',
#                           'close_approach_date_full': '2003-Nov-28 15:41',
#                           'epoch_date_close_approach': 1070034060000,
#                           'miss_distance': {'astronomical': '0.3309479304',
#                                             'kilometers': '49509105.468748248',
#                                             'lunar': '128.7387449256',
#                                             'miles': '30763531.6143639024'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27266.6708441394',
#                                                 'kilometers_per_second': '7.5740752345',
#                                                 'miles_per_hour': '16942.4488920154'}},
#                          {'close_approach_date': '2004-05-03',
#                           'close_approach_date_full': '2004-May-03 17:57',
#                           'epoch_date_close_approach': 1083607020000,
#                           'miss_distance': {'astronomical': '0.1969886346',
#                                             'kilometers': '29469080.150368302',
#                                             'lunar': '76.6285788594',
#                                             'miles': '18311237.3020824876'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26142.640122327',
#                                                 'kilometers_per_second': '7.2618444784',
#                                                 'miles_per_hour': '16244.019913787'}},
#                          {'close_approach_date': '2010-01-06',
#                           'close_approach_date_full': '2010-Jan-06 13:52',
#                           'epoch_date_close_approach': 1262785920000,
#                           'miss_distance': {'astronomical': '0.1258551451',
#                                             'kilometers': '18827661.635500937',
#                                             'lunar': '48.9576514439',
#                                             'miles': '11698966.4520174506'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '41891.0026432327',
#                                                 'kilometers_per_second': '11.6363896231',
#                                                 'miles_per_hour': '26029.4399479576'}},
#                          {'close_approach_date': '2010-09-27',
#                           'close_approach_date_full': '2010-Sep-27 21:53',
#                           'epoch_date_close_approach': 1285624380000,
#                           'miss_distance': {'astronomical': '0.447536186',
#                                             'kilometers': '66950460.17352382',
#                                             'lunar': '174.091576354',
#                                             'miles': '41601086.883795916'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29355.5781088409',
#                                                 'kilometers_per_second': '8.1543272525',
#                                                 'miles_per_hour': '18240.4146310184'}},
#                          {'close_approach_date': '2011-07-18',
#                           'close_approach_date_full': '2011-Jul-18 23:20',
#                           'epoch_date_close_approach': 1311031200000,
#                           'miss_distance': {'astronomical': '0.3838978931',
#                                             'kilometers': '57430307.105247697',
#                                             'lunar': '149.3362804159',
#                                             'miles': '35685538.0748123386'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '69611.3585663296',
#                                                 'kilometers_per_second': '19.3364884906',
#                                                 'miles_per_hour': '43253.7911047285'}},
#                          {'close_approach_date': '2016-11-14',
#                           'close_approach_date_full': '2016-Nov-14 21:24',
#                           'epoch_date_close_approach': 1479158640000,
#                           'miss_distance': {'astronomical': '0.3797958768',
#                                             'kilometers': '56816654.204062416',
#                                             'lunar': '147.7405960752',
#                                             'miles': '35304231.8434207008'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28993.2472802602',
#                                                 'kilometers_per_second': '8.0536798001',
#                                                 'miles_per_hour': '18015.2763447817'}},
#                          {'close_approach_date': '2017-06-07',
#                           'close_approach_date_full': '2017-Jun-07 19:17',
#                           'epoch_date_close_approach': 1496863020000,
#                           'miss_distance': {'astronomical': '0.1216010721',
#                                             'kilometers': '18191261.375876427',
#                                             'lunar': '47.3028170469',
#                                             'miles': '11303525.6675196126'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '24399.5180201911',
#                                                 'kilometers_per_second': '6.7776438945',
#                                                 'miles_per_hour': '15160.9116276015'}},
#                          {'close_approach_date': '2018-06-28',
#                           'close_approach_date_full': '2018-Jun-28 17:53',
#                           'epoch_date_close_approach': 1530208380000,
#                           'miss_distance': {'astronomical': '0.1299705404',
#                                             'kilometers': '19443316.006588948',
#                                             'lunar': '50.5585402156',
#                                             'miles': '12081516.3391375624'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8131.6590189974',
#                                                 'kilometers_per_second': '2.2587941719',
#                                                 'miles_per_hour': '5052.6966832209'}},
#                          {'close_approach_date': '2023-01-09',
#                           'close_approach_date_full': '2023-Jan-09 13:59',
#                           'epoch_date_close_approach': 1673272740000,
#                           'miss_distance': {'astronomical': '0.0725377631',
#                                             'kilometers': '10851494.854324597',
#                                             'lunar': '28.2171898459',
#                                             'miles': '6742806.2343975586'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32387.3201949256',
#                                                 'kilometers_per_second': '8.9964778319',
#                                                 'miles_per_hour': '20124.2212622303'}},
#                          {'close_approach_date': '2023-09-19',
#                           'close_approach_date_full': '2023-Sep-19 00:06',
#                           'epoch_date_close_approach': 1695081960000,
#                           'miss_distance': {'astronomical': '0.4367402777',
#                                             'kilometers': '65335415.287128499',
#                                             'lunar': '169.8919680253',
#                                             'miles': '40597544.5262673262'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28339.67125648',
#                                                 'kilometers_per_second': '7.8721309046',
#                                                 'miles_per_hour': '17609.1696204501'}},
#                          {'close_approach_date': '2024-07-22',
#                           'close_approach_date_full': '2024-Jul-22 14:57',
#                           'epoch_date_close_approach': 1721660220000,
#                           'miss_distance': {'astronomical': '0.4698906318',
#                                             'kilometers': '70294637.650234266',
#                                             'lunar': '182.7874557702',
#                                             'miles': '43679062.4108182308'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '78572.9531434817',
#                                                 'kilometers_per_second': '21.8258203176',
#                                                 'miles_per_hour': '48822.177468515'}},
#                          {'close_approach_date': '2029-11-08',
#                           'close_approach_date_full': '2029-Nov-08 09:24',
#                           'epoch_date_close_approach': 1888824240000,
#                           'miss_distance': {'astronomical': '0.4003635127',
#                                             'kilometers': '59893528.725637949',
#                                             'lunar': '155.7414064403',
#                                             'miles': '37216113.0160197362'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29746.2107470549',
#                                                 'kilometers_per_second': '8.2628363186',
#                                                 'miles_per_hour': '18483.1385611353'}},
#                          {'close_approach_date': '2030-06-20',
#                           'close_approach_date_full': '2030-Jun-20 05:07',
#                           'epoch_date_close_approach': 1908162420000,
#                           'miss_distance': {'astronomical': '0.065151004',
#                                             'kilometers': '9746451.42676148',
#                                             'lunar': '25.343740556',
#                                             'miles': '6056164.088529224'},
#                           'orbiting_body': 'Earth',
# ...
#                           'miss_distance': {'astronomical': '0.1150073498',
#                                             'kilometers': '17204854.564424926',
#                                             'lunar': '44.7378590722',
#                                             'miles': '10690600.8965829388'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '42267.875465615',
#                                                 'kilometers_per_second': '11.7410765182',
#                                                 'miles_per_hour': '26263.6140636206'}},
#                          {'close_approach_date': '2167-01-03',
#                           'close_approach_date_full': '2167-Jan-03 22:52',
#                           'epoch_date_close_approach': 6216994320000,
#                           'miss_distance': {'astronomical': '0.1705803017',
#                                             'kilometers': '25518449.798277379',
#                                             'lunar': '66.3557373613',
#                                             'miles': '15856429.4322466702'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22184.4523375272',
#                                                 'kilometers_per_second': '6.1623478715',
#                                                 'miles_per_hour': '13784.5559538374'}},
#                          {'close_approach_date': '2167-09-04',
#                           'close_approach_date_full': '2167-Sep-04 01:03',
#                           'epoch_date_close_approach': 6237997380000,
#                           'miss_distance': {'astronomical': '0.4019423508',
#                                             'kilometers': '60129719.542472796',
#                                             'lunar': '156.3555744612',
#                                             'miles': '37362875.1841487448'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25646.0087602751',
#                                                 'kilometers_per_second': '7.1238913223',
#                                                 'miles_per_hour': '15935.4324988499'}},
#                          {'close_approach_date': '2172-12-24',
#                           'close_approach_date_full': '2172-Dec-24 10:53',
#                           'epoch_date_close_approach': 6405475980000,
#                           'miss_distance': {'astronomical': '0.4677827083',
#                                             'kilometers': '69979296.784511321',
#                                             'lunar': '181.9674735287',
#                                             'miles': '43483118.6828893898'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '79561.3200654967',
#                                                 'kilometers_per_second': '22.1003666849',
#                                                 'miles_per_hour': '49436.3102373638'}},
#                          {'close_approach_date': '2173-11-02',
#                           'close_approach_date_full': '2173-Nov-02 13:07',
#                           'epoch_date_close_approach': 6432527220000,
#                           'miss_distance': {'astronomical': '0.4173354395',
#                                             'kilometers': '62432492.824713865',
#                                             'lunar': '162.3434859655',
#                                             'miles': '38793752.151086737'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30265.1729982097',
#                                                 'kilometers_per_second': '8.4069924995',
#                                                 'miles_per_hour': '18805.6015221376'}},
#                          {'close_approach_date': '2174-06-28',
#                           'close_approach_date_full': '2174-Jun-28 18:01',
#                           'epoch_date_close_approach': 6453108060000,
#                           'miss_distance': {'astronomical': '0.0341015598',
#                                             'kilometers': '5101520.709757626',
#                                             'lunar': '13.2655067622',
#                                             'miles': '3169937.9770661988'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32787.1242945445',
#                                                 'kilometers_per_second': '9.1075345263',
#                                                 'miles_per_hour': '20372.6439817963'}},
#                          {'close_approach_date': '2179-01-22',
#                           'close_approach_date_full': '2179-Jan-22 18:08',
#                           'epoch_date_close_approach': 6597310080000,
#                           'miss_distance': {'astronomical': '0.1265836114',
#                                             'kilometers': '18936638.642347718',
#                                             'lunar': '49.2410248346',
#                                             'miles': '11766681.6240777884'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8504.8216918608',
#                                                 'kilometers_per_second': '2.36245047',
#                                                 'miles_per_hour': '5284.5654562565'}},
#                          {'close_approach_date': '2180-01-11',
#                           'close_approach_date_full': '2180-Jan-11 07:20',
#                           'epoch_date_close_approach': 6627856800000,
#                           'miss_distance': {'astronomical': '0.1105450155',
#                                             'kilometers': '16537298.857916985',
#                                             'lunar': '43.0020110295',
#                                             'miles': '10275801.015084993'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25028.7339249116',
#                                                 'kilometers_per_second': '6.9524260903',
#                                                 'miles_per_hour': '15551.8819212874'}},
#                          {'close_approach_date': '2180-09-11',
#                           'close_approach_date_full': '2180-Sep-11 17:18',
#                           'epoch_date_close_approach': 6648974280000,
#                           'miss_distance': {'astronomical': '0.4212769782',
#                                             'kilometers': '63022138.618756434',
#                                             'lunar': '163.8767445198',
#                                             'miles': '39160141.0578254292'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27151.45885318',
#                                                 'kilometers_per_second': '7.5420719037',
#                                                 'miles_per_hour': '16870.8606412995'}},
#                          {'close_approach_date': '2186-11-06',
#                           'close_approach_date_full': '2186-Nov-06 01:20',
#                           'epoch_date_close_approach': 6843057600000,
#                           'miss_distance': {'astronomical': '0.4105135341',
#                                             'kilometers': '61411950.307532367',
#                                             'lunar': '159.6897647649',
#                                             'miles': '38159616.4361739846'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30109.4613674775',
#                                                 'kilometers_per_second': '8.3637392687',
#                                                 'miles_per_hour': '18708.8483702529'}},
#                          {'close_approach_date': '2187-06-26',
#                           'close_approach_date_full': '2187-Jun-26 02:35',
#                           'epoch_date_close_approach': 6863106900000,
#                           'miss_distance': {'astronomical': '0.0402688814',
#                                             'kilometers': '6024138.884722618',
#                                             'lunar': '15.6645948646',
#                                             'miles': '3743226.3272554084'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30164.8484439338',
#                                                 'kilometers_per_second': '8.3791245678',
#                                                 'miles_per_hour': '18743.263745621'}},
#                          {'close_approach_date': '2193-01-10',
#                           'close_approach_date_full': '2193-Jan-10 21:55',
#                           'epoch_date_close_approach': 7038136500000,
#                           'miss_distance': {'astronomical': '0.0817894841',
#                                             'kilometers': '12235532.609758867',
#                                             'lunar': '31.8161093149',
#                                             'miles': '7602807.4168396846'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28593.44966889',
#                                                 'kilometers_per_second': '7.942624908',
#                                                 'miles_per_hour': '17766.8576567611'}},
#                          {'close_approach_date': '2193-09-16',
#                           'close_approach_date_full': '2193-Sep-16 23:45',
#                           'epoch_date_close_approach': 7059656700000,
#                           'miss_distance': {'astronomical': '0.4305087827',
#                                             'kilometers': '64403196.908212849',
#                                             'lunar': '167.4679164703',
#                                             'miles': '40018290.8859573562'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27940.084496338',
#                                                 'kilometers_per_second': '7.7611345823',
#                                                 'miles_per_hour': '17360.8819471829'}},
#                          {'close_approach_date': '2194-07-26',
#                           'close_approach_date_full': '2194-Jul-26 00:59',
#                           'epoch_date_close_approach': 7086617940000,
#                           'miss_distance': {'astronomical': '0.4917914185',
#                                             'kilometers': '73570948.691878595',
#                                             'lunar': '191.3068617965',
#                                             'miles': '45714867.690550811'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '81012.3886727089',
#                                                 'kilometers_per_second': '22.503441298',
#                                                 'miles_per_hour': '50337.9478394396'}},
#                          {'close_approach_date': '2199-11-12',
#                           'close_approach_date_full': '2199-Nov-12 07:53',
#                           'epoch_date_close_approach': 7253826780000,
#                           'miss_distance': {'astronomical': '0.3929848393',
#                                             'kilometers': '58789694.901572291',
#                                             'lunar': '152.8711024877',
#                                             'miles': '36530222.4829119758'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29592.5208496177',
#                                                 'kilometers_per_second': '8.2201446804',
#                                                 'miles_per_hour': '18387.6416356972'}},
#                          {'close_approach_date': '2200-06-17',
#                           'close_approach_date_full': '2200-Jun-17 14:09',
#                           'epoch_date_close_approach': 7272598140000,
#                           'miss_distance': {'astronomical': '0.0919065426',
#                                             'kilometers': '13749023.012024262',
#                                             'lunar': '35.7516450714',
#                                             'miles': '8543246.7440563356'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '25705.1818470906',
#                                                 'kilometers_per_second': '7.1403282909',
#                                                 'miles_per_hour': '15972.2003538214'}}],
#  'designation': '226554',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 2301.5744618737,
#                                  'estimated_diameter_min': 1029.2953904054},
#                         'kilometers': {'estimated_diameter_max': 0.7015198735,
#                                        'estimated_diameter_min': 0.313729225},
#                         'meters': {'estimated_diameter_max': 701.5198735305,
#                                    'estimated_diameter_min': 313.7292249562},
#                         'miles': {'estimated_diameter_max': 0.4359041053,
#                                   'estimated_diameter_min': 0.1949422422}},
#  'id': '2226554',
#  'is_potentially_hazardous_asteroid': True,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=DEMO_KEY'},
#  'name': '226554 (2003 WR21)',
#  'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2226554',
#  'neo_reference_id': '2226554',
#  'orbital_data': {'aphelion_distance': '1.410933107750826',
#                   'ascending_node_longitude': '85.77597680520282',
#                   'data_arc_in_days': 11725,
#                   'eccentricity': '.2616161411601777',
#                   'epoch_osculation': '2460000.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '1990-10-24',
#                   'inclination': '9.264880469231187',
#                   'jupiter_tisserand_invariant': '5.536',
#                   'last_observation_date': '2022-11-30',
#                   'mean_anomaly': '343.0403320779595',
#                   'mean_motion': '.8333650683445789',
#                   'minimum_orbit_intersection': '.0302692',
#                   'observations_used': 334,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'which cross the '
#                                                              'Earth’s orbit '
#                                                              'similar to that '
#                                                              'of 1862 Apollo',
#                                   'orbit_class_range': 'a (semi-major axis) > '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '< 1.017 AU',
#                                   'orbit_class_type': 'APO'},
#                   'orbit_determination_date': '2022-12-01 05:30:51',
#                   'orbit_id': '87',
#                   'orbit_uncertainty': '0',
#                   'orbital_period': '431.98354919665',
#                   'perihelion_argument': '108.0903706214268',
#                   'perihelion_distance': '.8257743371195874',
#                   'perihelion_time': '2460020.850826505999',
#                   'semi_major_axis': '1.118353722435207'}}

# %% [markdown]
# Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".
#
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
# * use a loop if that is easier to understand - we will look at more compact algorithms to solve this problem in class.
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
# your code here

# %% [markdown]
# ## OPTIONAL - Take your skills to the next level...
# ## Exercise 3
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, which it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
# your code here
